# %%
# !pip install pyshp
# !pip install requests # For API call
# !pip install geopandas
# !pip install geoplot
# !pip install mapclassify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 KB 2.1 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 48.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 59.4 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 48.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import shapefile as shp
import requests as rq
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import os
import sys
import itertools
import warnings
import geopandas as gpd
import geoplot as gplt
import geoplot.crs as gcrs
import mapclassify as mc
from shapely.geometry import Point, Polygon
import pyproj

warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
#load data
sf_city = shp.Reader("/gdrive/My Drive/CS506-DS/data/City_Council_Districts_-_Effective_for_the_2023_Municipal_Election.shp")
parks = pd.read_csv("/gdrive/My Drive/CS506-DS/data/Parks.csv")
parks.Location.unique()
# Out:
# array(['Dorchester', 'Hyde Park', 'East Boston', 'South Boston',
#        'Fenway/Longwood', 'Roxbury', 'West Roxbury',
#        'Back Bay/Beacon Hill', 'Jamaica Plain', 'Charlestown',
#        'Allston-Brighton', 'Central Boston', 'Mattapan', 'Roslindale',
#        'Mission Hill', 'South End'], dtype=object)
