# %% [markdown]
# ### Key Question : Are there patterns in terms of type of violence in District 4? How does this compare to the rest of the city?

# %% [markdown]
# ### Data : CRIME INCIDENT REPORTS - 2023 TO PRESENT : https://data.boston.gov/dataset/crime-incident-reports-august-2015-to-date-source-new-system/resource/b973d8cb-eeb2-4e7e-99da-c92938efc9c0

# %% [markdown]
# ### Patterns in terms of types of violence :
#
# Based on the "Count of crimes of all Police Districts of D4 vs Boston city" graph, the most frequent crimes involving shooting are:
#
# - Investigate Property
# - Ballistics evidence / Found
# - Assault - Aggravated
# - Vandalism
# - Investigate Person
# - Murder, Non-Negligent Manslaughter
#
# From the "Count of some crimes of all Police Districts of D4 vs Boston city (2019-2023)" data, it is evident that:
#
# - Both D4 and the rest of the city experienced a significant decrease in crime rates starting from 2020. However, for Ballistics evidence, this decrease began in 2021.
# - 2020 witnessed a significant increase in most types of crimes, leading to a peak for all crimes. This could be a possible response to the lockdown measures.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
crime_df = pd.read_csv("../../../data/police_reports/police_reports_boston.csv")
crime_df=crime_df[crime_df['SHOOTING']==1]
crime_df=crime_df[['OFFENSE_DESCRIPTION','DISTRICT','Location']]

crime_df_22 = pd.read_csv("../../../data/police_reports/police_reports_2022.csv")
crime_df_22=crime_df_22[crime_df_22['SHOOTING']==1]
crime_df_22=crime_df_22[['OFFENSE_DESCRIPTION','DISTRICT','Location']]

crime_df_21 = pd.read_csv("../../../data/police_reports/police_reports_2021.csv")
crime_df_21=crime_df_21[crime_df_21['SHOOTING']==1]
crime_df_21=crime_df_21[['OFFENSE_DESCRIPTION','DISTRICT','Location']]

crime_df_20 = pd.read_csv("../../../data/police_reports/police_reports_2020.csv")
crime_df_20=crime_df_20[crime_df_20['SHOOTING']==1]
crime_df_20=crime_df_20[['OFFENSE_DESCRIPTION','DISTRICT','Location']]

crime_df_19 = pd.read_csv("../../../data/police_reports/police_reports_2019.csv")
crime_df_19=crime_df_19[crime_df_19['SHOOTING']==1]
crime_df_19=crime_df_19[['OFFENSE_DESCRIPTION','DISTRICT','Location']]

crime_df_18 = pd.read_csv("../../../data/police_reports/police_reports_2018.csv")
crime_df_18=crime_df_18[crime_df_18['SHOOTING']=='Y']
crime_df_18=crime_df_18[['OFFENSE_DESCRIPTION','DISTRICT','Location']]

crime_df_17 = pd.read_csv("../../../data/police_reports/police_reports_2017.csv")
crime_df_17=crime_df_17[crime_df_17['SHOOTING']=='Y']
crime_df_17=crime_df_17[['OFFENSE_DESCRIPTION','DISTRICT','Location']]

crime_df_16 = pd.read_csv("../../../data/police_reports/police_reports_2016.csv")
crime_df_16=crime_df_16[crime_df_16['SHOOTING']=='Y']
crime_df_16=crime_df_16[['OFFENSE_DESCRIPTION','DISTRICT','Location']]

crime_df_15 = pd.read_csv("../../../data/police_reports/police_reports_2015.csv")
crime_df_15=crime_df_15[crime_df_15['SHOOTING']=='Y']
crime_df_15=crime_df_15[['OFFENSE_DESCRIPTION','DISTRICT','Location']]

# %%
B3_df=crime_df[crime_df['DISTRICT']=='B3']
C11_df=crime_df[crime_df['DISTRICT']=='C11']
E13_df=crime_df[crime_df['DISTRICT']=='E13']
NotD4=crime_df[~crime_df['DISTRICT'].isin(['B3','C11','E13'])]
D4=crime_df[crime_df['DISTRICT'].isin(['B3','C11','E13'])]

# %%
D4_22=crime_df_22[crime_df_22['DISTRICT'].isin(['B3','C11','E13'])]
D4_21=crime_df_21[crime_df_21['DISTRICT'].isin(['B3','C11','E13'])]
D4_20=crime_df_20[crime_df_20['DISTRICT'].isin(['B3','C11','E13'])]
D4_19=crime_df_19[crime_df_19['DISTRICT'].isin(['B3','C11','E13'])]
D4_18=crime_df_18[crime_df_18['DISTRICT'].isin(['B3','C11','E13'])]
D4_17=crime_df_17[crime_df_17['DISTRICT'].isin(['B3','C11','E13'])]
D4_16=crime_df_16[crime_df_16['DISTRICT'].isin(['B3','C11','E13'])]
D4_15=crime_df_15[crime_df_15['DISTRICT'].isin(['B3','C11','E13'])]

# %% [markdown]
# Count of all reports by type of crime:

# %% [markdown]
# For Boston city:

# %%
plt.figure(figsize=(20,10))
crime_df['OFFENSE_DESCRIPTION'].value_counts().plot.bar()
plt.title("Boston City: no of crimes involving shooting (2023)",fontsize = 30)
plt.ylabel("no of crime reports")
plt.xlabel("crime type")
plt.show()

# %% [markdown]
# For Police District B3:

# %%
plt.figure(figsize=(20,10))
B3_df['OFFENSE_DESCRIPTION'].value_counts().plot.bar()
plt.title("District B3 : no of crimes involving shooting (2023)",fontsize = 30)
plt.ylabel("no of crime reports")
plt.xlabel("crime type")
plt.show()

# %% [markdown]
# Crime patterns of B3 vs Boston city

# %%
offence=B3_df['OFFENSE_DESCRIPTION'].unique().tolist()
crime_radio_B3=crime_df[crime_df['OFFENSE_DESCRIPTION'].isin(offence)]

plt.figure(figsize=(20,10))
plt.bar(crime_radio_B3['OFFENSE_DESCRIPTION'],B3_df.groupby(['OFFENSE_DESCRIPTION'])['OFFENSE_DESCRIPTION'].transform('count')/crime_radio_B3.groupby(['OFFENSE_DESCRIPTION'])['OFFENSE_DESCRIPTION'].transform('count'))
plt.title("Crime rate of District B3/ Crime rate of Boston City for each type of crime",fontsize = 30)
plt.ylabel("Percentage of reports from B3")
plt.xlabel("crime type")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Crime patterns of B3 vs other districts:

# %%
NotB3=crime_df[crime_df['DISTRICT']!='B3']

plt.figure(figsize=(20,10))
NotB3['OFFENSE_DESCRIPTION'].value_counts().plot(kind='bar',color='red')
B3_df['OFFENSE_DESCRIPTION'].value_counts().plot(kind='bar',color="blue")
plt.title("no of crime reports involving shooting (by type of crime) outside B3 and in B3 (2023)",fontsize = 30)
plt.ylabel("no of crime reports")
plt.xlabel("crime type")
plt.legend(['crime reports from districs other than B3','crime reports from B3'])
plt.show()

# %% [markdown]
# For Police District C11:

# %%
plt.figure(figsize=(20,10))
C11_df['OFFENSE_DESCRIPTION'].value_counts().plot.bar()
plt.title("District C11 :no of crimes involving shooting (2023)",fontsize = 30)
plt.ylabel("no of crime reports")
plt.xlabel("crime type")
plt.show()

# %% [markdown]
# Crime patterns of C11 vs Boston city

# %%
offence=C11_df['OFFENSE_DESCRIPTION'].unique().tolist()
crime_radio_C11=crime_df[crime_df['OFFENSE_DESCRIPTION'].isin(offence)]

plt.figure(figsize=(20,10))
plt.bar(crime_radio_C11['OFFENSE_DESCRIPTION'],C11_df.groupby(['OFFENSE_DESCRIPTION'])['OFFENSE_DESCRIPTION'].transform('count')/crime_radio_C11.groupby(['OFFENSE_DESCRIPTION'])['OFFENSE_DESCRIPTION'].transform('count'))
plt.title("Crime rate of District C11/ Crime rate of Boston City for each type of crime",fontsize = 30)
plt.ylabel("Percentage of reports from C11")
plt.xlabel("crime type")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Crime patterns of C11 vs other districts:

# %%
NotC11=crime_df[crime_df['DISTRICT']!='C11']

plt.figure(figsize=(20,10))
NotC11['OFFENSE_DESCRIPTION'].value_counts().plot(kind='bar',color='red')
C11_df['OFFENSE_DESCRIPTION'].value_counts().plot(kind='bar',color="blue")
plt.title("no of crime reports involving shooting (by type of crime) outside C11 and in C11 (2023)",fontsize = 30)
plt.ylabel("no of crime reports")
plt.xlabel("crime type")
plt.legend(['crime reports from districs other than C11','crime reports from C11'])
plt.show()

# %% [markdown]
# For Police District E13:

# %%
plt.figure(figsize=(20,10))
E13_df['OFFENSE_DESCRIPTION'].value_counts().plot.bar()
plt.title("District E13 : no of crimes involving shooting (2023)",fontsize = 30)
plt.ylabel("no of crime reports")
plt.xlabel("crime type")
plt.show()

# %% [markdown]
# Crime patterns of E13 vs Boston city

# %%
offence=E13_df['OFFENSE_DESCRIPTION'].unique().tolist()
crime_radio_E13=crime_df[crime_df['OFFENSE_DESCRIPTION'].isin(offence)]

plt.figure(figsize=(20,10))
plt.bar(crime_radio_E13['OFFENSE_DESCRIPTION'],E13_df.groupby(['OFFENSE_DESCRIPTION'])['OFFENSE_DESCRIPTION'].transform('count')/crime_radio_E13.groupby(['OFFENSE_DESCRIPTION'])['OFFENSE_DESCRIPTION'].transform('count'))
plt.title("Crime rate of District E13/ Crime rate of Boston City for each type of crime",fontsize = 30)
plt.ylabel("Percentage of reports from E13")
plt.xlabel("crime type")
plt.xticks(rotation=90)
plt.show()

# %%
NotE13=crime_df[crime_df['DISTRICT']!='E13']

plt.figure(figsize=(20,10))
NotE13['OFFENSE_DESCRIPTION'].value_counts().plot(kind='bar',color='red')
E13_df['OFFENSE_DESCRIPTION'].value_counts().plot(kind='bar',color="blue")
plt.title("no of crime reports involving shooting (by type of crime) outside E13 and in E13 (2023)",fontsize = 30)
plt.ylabel("no of crime reports")
plt.xlabel("crime type")
plt.legend(['crime reports from districs other than E13','crime reports from E13'])
plt.show()

# %% [markdown]
# For all D4 (B3, C11, E13):

# %%
plt.figure(figsize=(20,10))
D4['OFFENSE_DESCRIPTION'].value_counts().plot.bar()
plt.title("District D4 : no of crimes involving shooting (2023)",fontsize = 30)
plt.ylabel("no of crime reports")
plt.xlabel("crime type")
plt.show()

# %% [markdown]
# No of crime reports by type of crime in district 4 from 2019-2023

# %%
offences=[]
offence=D4['OFFENSE_DESCRIPTION'].unique().tolist()
crime_radio_D4=crime_df[crime_df['OFFENSE_DESCRIPTION'].isin(offence)]
offences.extend(offence)

# %%
offence_22=D4_22['OFFENSE_DESCRIPTION'].unique().tolist()
crime_radio_D4_22=crime_df_22[crime_df_22['OFFENSE_DESCRIPTION'].isin(offence_22)]
offences.extend(x for x in offence_22 if x not in offences)

offence_21=D4_21['OFFENSE_DESCRIPTION'].unique().tolist()
crime_radio_D4_21=crime_df_21[crime_df_21['OFFENSE_DESCRIPTION'].isin(offence_21)]
offences.extend(x for x in offence_21 if x not in offences)

offence_20=D4_20['OFFENSE_DESCRIPTION'].unique().tolist()
crime_radio_D4_20=crime_df_20[crime_df_20['OFFENSE_DESCRIPTION'].isin(offence_20)]
offences.extend(x for x in offence_20 if x not in offences)

offence_19=D4_19['OFFENSE_DESCRIPTION'].unique().tolist()
crime_radio_D4_19=crime_df_19[crime_df_19['OFFENSE_DESCRIPTION'].isin(offence_19)]
offences.extend(x for x in offence_19 if x not in offences)

# %%
#offence_18=D4_18['OFFENSE_DESCRIPTION'].unique().tolist()
#crime_radio_D4_18=crime_df_18[crime_df_18['OFFENSE_DESCRIPTION'].isin(offence_18)]
#offences.extend(x for x in offence_18 if x not in offences)

#offence_17=D4_17['OFFENSE_DESCRIPTION'].unique().tolist()
#crime_radio_D4_17=crime_df_17[crime_df_17['OFFENSE_DESCRIPTION'].isin(offence_17)]
#offences.extend(x for x in offence_17 if x not in offences)

#offence_16=D4_16['OFFENSE_DESCRIPTION'].unique().tolist()
#crime_radio_D4_16=crime_df_16[crime_df_16['OFFENSE_DESCRIPTION'].isin(offence_16)]
#offences.extend(x for x in offence_16 if x not in offences)

#offence_15=D4_15['OFFENSE_DESCRIPTION'].unique().tolist()
#crime_radio_D4_15=crime_df_15[crime_df_15['OFFENSE_DESCRIPTION'].isin(offence_15)]
#offences.extend(x for x in offence_15 if x not in offences)

#crime_radio_D4_18["Offence Index"]=crime_radio_D4_18['OFFENSE_DESCRIPTION'].apply(offence_index)
#D4_18["Offence Index"]=D4_18['OFFENSE_DESCRIPTION'].apply(offence_index)

#crime_radio_D4_17["Offence Index"]=crime_radio_D4_17['OFFENSE_DESCRIPTION'].apply(offence_index)
#D4_17["Offence Index"]=D4_17['OFFENSE_DESCRIPTION'].apply(offence_index)

#crime_radio_D4_16["Offence Index"]=crime_radio_D4_16['OFFENSE_DESCRIPTION'].apply(offence_index)
#D4_16["Offence Index"]=D4_16['OFFENSE_DESCRIPTION'].apply(offence_index)

#crime_radio_D4_15["Offence Index"]=crime_radio_D4_15['OFFENSE_DESCRIPTION'].apply(offence_index)
#D4_15["Offence Index"]=D4_15['OFFENSE_DESCRIPTION'].apply(offence_index)

# %%
offence_ind=[(x*2)+1.5 for x in range(0,len(offences))]

def offence_index(x):
    return (offences.index(x)*2)+1



crime_radio_D4["Offence Index"]=crime_radio_D4['OFFENSE_DESCRIPTION'].apply(offence_index)
D4["Offence Index"]=D4['OFFENSE_DESCRIPTION'].apply(offence_index)
crime_radio_D4_22["Offence Index"]=crime_radio_D4_22['OFFENSE_DESCRIPTION'].apply(offence_index)
D4_22["Offence Index"]=D4_22['OFFENSE_DESCRIPTION'].apply(offence_index)

crime_radio_D4_21["Offence Index"]=crime_radio_D4_21['OFFENSE_DESCRIPTION'].apply(offence_index)
D4_21["Offence Index"]=D4_21['OFFENSE_DESCRIPTION'].apply(offence_index)

crime_radio_D4_20["Offence Index"]=crime_radio_D4_20['OFFENSE_DESCRIPTION'].apply(offence_index)
D4_20["Offence Index"]=D4_20['OFFENSE_DESCRIPTION'].apply(offence_index)

crime_radio_D4_19["Offence Index"]=crime_radio_D4_19['OFFENSE_DESCRIPTION'].apply(offence_index)
D4_19["Offence Index"]=D4_19['OFFENSE_DESCRIPTION'].apply(offence_index)

# %%
plt.figure(figsize=(20,10))
index=crime_radio_D4_19['Offence Index'].to_numpy()
plt.bar(index,crime_radio_D4_19.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2019 all districts')
index1=D4_19['Offence Index'].to_numpy()
plt.bar(index1,D4_19.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2019 district 4')

index=crime_radio_D4_20['Offence Index'].to_numpy()
index=[x+0.3 for x in index]
plt.bar(index,crime_radio_D4_20.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2020 all districts')
index1=D4_20['Offence Index'].to_numpy()
index1=[x+0.3 for x in index1]
plt.bar(index1,D4_20.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2020 district 4')

index=crime_radio_D4_21['Offence Index'].to_numpy()
index=[x+0.6 for x in index]
plt.bar(index,crime_radio_D4_21.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2021 all districts')
index1=D4_21['Offence Index'].to_numpy()
index1=[x+0.6 for x in index1]
plt.bar(index1,D4_21.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2021 district 4')


index=crime_radio_D4_22['Offence Index'].to_numpy()
index=[x+0.9 for x in index]
plt.bar(index,crime_radio_D4_22.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2022 all districts')
index1=D4_22['Offence Index'].to_numpy()
index1=[x+0.9 for x in index1]
plt.bar(index1,D4_22.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2022 district 4')

index=crime_radio_D4['Offence Index'].to_numpy()
index=[x+1.2 for x in index]
plt.bar(index,crime_radio_D4.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2023 all districts')
index1=D4['Offence Index'].to_numpy()
index1=[x+1.2 for x in index1]
plt.bar(index1,D4.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2023 district 4')

plt.title("Count of crimes of all Police Districts of D4 vs Boston city",fontsize = 30)
plt.xlabel("OFFENSE_DESCRIPTION")
plt.legend(bbox_to_anchor=(1, 1.05))
plt.xticks(offence_ind, offences)
plt.tick_params(axis='x', labelrotation = 90)
plt.show()

# %% [markdown]
# Top most occurring type of crime and its count in district 4 from 2019-2023

# %%
offences=offences[0:10]
D4_22=D4_22[D4_22['OFFENSE_DESCRIPTION'].isin(offences)]
D4_21=D4_21[D4_21['OFFENSE_DESCRIPTION'].isin(offences)]
D4_20=D4_20[D4_20['OFFENSE_DESCRIPTION'].isin(offences)]
D4_19=D4_19[D4_19['OFFENSE_DESCRIPTION'].isin(offences)]
crime_radio_D4_22=crime_radio_D4_22[crime_radio_D4_22['OFFENSE_DESCRIPTION'].isin(offences)]
crime_radio_D4_21=crime_radio_D4_21[crime_radio_D4_21['OFFENSE_DESCRIPTION'].isin(offences)]
crime_radio_D4_20=crime_radio_D4_20[crime_radio_D4_20['OFFENSE_DESCRIPTION'].isin(offences)]
crime_radio_D4_19=crime_radio_D4_19[crime_radio_D4_19['OFFENSE_DESCRIPTION'].isin(offences)]

offence_ind=[(x*2)+1.5 for x in range(0,len(offences))]

def offence_index(x):
    return (offences.index(x)*2)+1



crime_radio_D4["Offence Index"]=crime_radio_D4['OFFENSE_DESCRIPTION'].apply(offence_index)
D4["Offence Index"]=D4['OFFENSE_DESCRIPTION'].apply(offence_index)
crime_radio_D4_22["Offence Index"]=crime_radio_D4_22['OFFENSE_DESCRIPTION'].apply(offence_index)
D4_22["Offence Index"]=D4_22['OFFENSE_DESCRIPTION'].apply(offence_index)

crime_radio_D4_21["Offence Index"]=crime_radio_D4_21['OFFENSE_DESCRIPTION'].apply(offence_index)
D4_21["Offence Index"]=D4_21['OFFENSE_DESCRIPTION'].apply(offence_index)

crime_radio_D4_20["Offence Index"]=crime_radio_D4_20['OFFENSE_DESCRIPTION'].apply(offence_index)
D4_20["Offence Index"]=D4_20['OFFENSE_DESCRIPTION'].apply(offence_index)

crime_radio_D4_19["Offence Index"]=crime_radio_D4_19['OFFENSE_DESCRIPTION'].apply(offence_index)
D4_19["Offence Index"]=D4_19['OFFENSE_DESCRIPTION'].apply(offence_index)

# %%
plt.figure(figsize=(20,10))
index=crime_radio_D4_19['Offence Index'].to_numpy()
plt.bar(index,crime_radio_D4_19.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2019 all districts')
index1=D4_19['Offence Index'].to_numpy()
plt.bar(index1,D4_19.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2019 district 4')

index=crime_radio_D4_20['Offence Index'].to_numpy()
index=[x+0.3 for x in index]
plt.bar(index,crime_radio_D4_20.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2020 all districts')
index1=D4_20['Offence Index'].to_numpy()
index1=[x+0.3 for x in index1]
plt.bar(index1,D4_20.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2020 district 4')

index=crime_radio_D4_21['Offence Index'].to_numpy()
index=[x+0.6 for x in index]
plt.bar(index,crime_radio_D4_21.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2021 all districts')
index1=D4_21['Offence Index'].to_numpy()
index1=[x+0.6 for x in index1]
plt.bar(index1,D4_21.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2021 district 4')


index=crime_radio_D4_22['Offence Index'].to_numpy()
index=[x+0.9 for x in index]
plt.bar(index,crime_radio_D4_22.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2022 all districts')
index1=D4_22['Offence Index'].to_numpy()
index1=[x+0.9 for x in index1]
plt.bar(index1,D4_22.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2022 district 4')

index=crime_radio_D4['Offence Index'].to_numpy()
index=[x+1.2 for x in index]
plt.bar(index,crime_radio_D4.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2023 all districts')
index1=D4['Offence Index'].to_numpy()
index1=[x+1.2 for x in index1]
plt.bar(index1,D4.groupby('Offence Index')['OFFENSE_DESCRIPTION'].transform('count'),0.3,label='2023 district 4')

plt.title("Count some of the crimes of all Police Districts of D4 vs Boston city (2019-2023)",fontsize = 20)
plt.xlabel("OFFENSE_DESCRIPTION")
plt.legend(bbox_to_anchor=(1, 1.05))
plt.xticks(offence_ind, offences)
plt.tick_params(axis='x', labelrotation = 90)
plt.show()

# %% [markdown]
# Count of crimes of all Police Districts of D4 vs Boston city:

# %%
plt.figure(figsize=(20,10))
crime_radio_D4['OFFENSE_DESCRIPTION'].value_counts().plot(kind='bar',color="red")
D4['OFFENSE_DESCRIPTION'].value_counts().plot(kind='bar',color="blue")
plt.title("Count of crimes involving shooting of all Police Districts of D4 vs Boston city (2023):",fontsize = 30)
plt.ylabel("no of crime reports")
plt.xlabel("crime type")
plt.show()

# %% [markdown]
# Crime patterns of all Police Districts of D4 vs Boston city:

# %%
plt.figure(figsize=(20,10))
plt.bar(crime_radio_D4['OFFENSE_DESCRIPTION'],D4.groupby(['OFFENSE_DESCRIPTION'])['OFFENSE_DESCRIPTION'].transform('count')/crime_radio_D4.groupby(['OFFENSE_DESCRIPTION'])['OFFENSE_DESCRIPTION'].transform('count'))
plt.title("Crime rate of Districts other than in D4/ Crime rate of Boston City for each type of crime (2023)",fontsize = 25)
plt.ylabel("Percentage of reports from districts other than in D4 (2023)")
plt.xlabel("crime type")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# For Other districts (not D4)

# %%
plt.figure(figsize=(20,10))
NotD4['OFFENSE_DESCRIPTION'].value_counts().plot.bar()
plt.title("Districts not in D4 : no of crimes involving shooting (2023)",fontsize = 30)
plt.ylabel("no of crime reports")
plt.xlabel("crime type")
plt.show()

# %% [markdown]
# Crime patterns of all other Police Districts vs Boston city:

# %%
offence=NotD4['OFFENSE_DESCRIPTION'].unique().tolist()
crime_radio_NotD4=crime_df[crime_df['OFFENSE_DESCRIPTION'].isin(offence)]

plt.figure(figsize=(20,10))
plt.bar(crime_radio_NotD4['OFFENSE_DESCRIPTION'],NotD4.groupby(['OFFENSE_DESCRIPTION'])['OFFENSE_DESCRIPTION'].transform('count')/crime_radio_NotD4.groupby(['OFFENSE_DESCRIPTION'])['OFFENSE_DESCRIPTION'].transform('count'))
plt.title("Crime rate of Districts other than in D4/ Crime rate of Boston City for each type of crime",fontsize = 25)
plt.ylabel("Percentage of reports from districts other than in D4")
plt.xlabel("crime type")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Crime patterns of D4 vs all other districs:

# %%
plt.figure(figsize=(20,10))
D4['OFFENSE_DESCRIPTION'].value_counts().plot(kind='bar',color="blue")
NotD4['OFFENSE_DESCRIPTION'].value_counts().plot(kind='bar',color='red')
plt.title("no of crime reports involving shooting outside D4 and in D4 (2023)",fontsize = 30)
plt.ylabel("no of crime reports")
plt.xlabel("crime type")
plt.legend(['crime reports from districs other than D4','crime reports from D4'])
plt.show()
