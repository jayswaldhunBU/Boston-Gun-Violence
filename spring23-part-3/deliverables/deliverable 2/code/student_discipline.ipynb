# %% [markdown]
# ### Data: Student Discipline Data Report - All Offenses - All Students : https://profiles.doe.mass.edu/statereport/ssdr.aspx

# %% [markdown]
# ### Key insights on Student Discipline Data Report:
# Based on the "Percentage of Students Disciplined" metric:
#
# - B3 had the highest percentage of students being disciplined until the 2017-2018 academic year.
# - However, the percentage has decreased significantly since 2018-2019 and has continued to consistently decrease.
# - C11 has a higher percentage of students being disciplined.
# - Nonetheless, C11 has maintained a lower percentage since 2017-2018.
#
# Based on the "Number of Students per District" metric:
#
# - Non-district4 schools have shown a slight decrease in the number of students each year since 2014-2015.
# - B3 has experienced an increase or maintained a similar student count over the years.
# - E13 has maintained its student count while C11 has followed the pattern of non-district4 schools.
#
# From the "Number of Students Disciplined per District" metric, it can be observed that there has been a decrease in the number of students disciplined across District4 since the 2016-2017 academic year.
#
# Based on the "Percentage of Students Disciplined for Felony per District" metric, there have been no students disciplined for felony convictions or complaints in District4 between 2012 and 2022.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
##Do not run this code
##Data is unavailable

#This code was used to create csv files

def add_districts(x):
    B3=["KIPP Academy Boston Charter School","Taylor Elementary School","Mildred Avenue K-8","Chittick Elementary School",
    "Young Achievers Science and Math School","Dr. Catherine Ellison-Rosa Parks Early Ed School",
    "Grove Hall Child Development Center","Jubilee Academy Pre-School","Sparks Center","Boston Nature Center",
    "Mattapan Head Start","Necub Day Care","La Ronde De Marie Claire Elc","Tabitha House Day Care","Mattahunt Elementary School"]

    E13=["Boston Teachers Union School","Curley K-8 School","Elc - West Zone","John F Kennedy","Joseph P Manning","Mission Hill School"]

    C11=["Dr. William Henderson Lower","Edward Everett","John Winthrop","Joseph Lee","King K-8","Lee Academy",
    "Mather","O W Holmes","Paul A Dever"]

    for d in B3:
        if d in x and "Boston" in x:
            return "B3"
    
    for d in E13:
        if d in x and "Boston" in x:
            return "E13"

    for d in C11:
        if d in x and "Boston" in x:
            return "C11"

    return "not D4"


student_data_2122_allOffence = pd.read_excel('../../data/student_data/Student21-22_allOffence.xlsx')
student_data_2122_allOffence=student_data_2122_allOffence[student_data_2122_allOffence['School Name'].str.contains('Boston')]
student_data_2122_allOffence['district']=student_data_2122_allOffence['School Name'].apply(add_districts)
student_data_2122_allOffence.to_csv('../../data/student_data/student_data_2122_allOffence.csv')

student_data_2021_allOffence = pd.read_excel('../../data/student_data/Student20-21_allOffence.xlsx')
student_data_2021_allOffence=student_data_2021_allOffence[student_data_2021_allOffence['School Name'].str.contains('Boston')]
student_data_2021_allOffence['district']=student_data_2021_allOffence['School Name'].apply(add_districts)
student_data_2021_allOffence.to_csv('../../data/student_data/student_data_2021_allOffence.csv')

student_data_1920_allOffence = pd.read_excel('../../data/student_data/Student19-20_allOffence.xlsx')
student_data_1920_allOffence=student_data_1920_allOffence[student_data_1920_allOffence['School Name'].str.contains('Boston')]
student_data_1920_allOffence['district']=student_data_1920_allOffence['School Name'].apply(add_districts)
student_data_1920_allOffence.to_csv('../../data/student_data/student_data_1920_allOffence.csv')

student_data_1819_allOffence = pd.read_excel('../../data/student_data/Student18-19_allOffence.xlsx')
student_data_1819_allOffence=student_data_1819_allOffence[student_data_1819_allOffence['School Name'].str.contains('Boston')]
student_data_1819_allOffence['district']=student_data_1819_allOffence['School Name'].apply(add_districts)
student_data_1819_allOffence.to_csv('../../data/student_data/student_data_1819_allOffence.csv')

student_data_1718_allOffence = pd.read_excel('../../data/student_data/Student17-18_allOffence.xlsx')
student_data_1718_allOffence=student_data_1718_allOffence[student_data_1718_allOffence['School Name'].str.contains('Boston')]
student_data_1718_allOffence['district']=student_data_1718_allOffence['School Name'].apply(add_districts)
student_data_1718_allOffence.to_csv('../../data/student_data/student_data_1718_allOffence.csv')

student_data_1617_allOffence = pd.read_excel('../../data/student_data/Student16-17_allOffence.xlsx')
student_data_1617_allOffence=student_data_1617_allOffence[student_data_1617_allOffence['School Name'].str.contains('Boston')]
student_data_1617_allOffence['district']=student_data_1617_allOffence['School Name'].apply(add_districts)
student_data_1617_allOffence.to_csv('../../data/student_data/student_data_1617_allOffence.csv')

student_data_1516_allOffence = pd.read_excel('../../data/student_data/Student15-16_allOffence.xlsx')
student_data_1516_allOffence=student_data_1516_allOffence[student_data_1516_allOffence['School Name'].str.contains('Boston')]
student_data_1516_allOffence['district']=student_data_1516_allOffence['School Name'].apply(add_districts)
student_data_1516_allOffence.to_csv('../../data/student_data/student_data_1516_allOffence.csv')

student_data_1415_allOffence = pd.read_excel('../../data/student_data/Student14-15_allOffence.xlsx')
student_data_1415_allOffence=student_data_1415_allOffence[student_data_1415_allOffence['School Name'].str.contains('Boston')]
student_data_1415_allOffence['district']=student_data_1415_allOffence['School Name'].apply(add_districts)
student_data_1415_allOffence.to_csv('../../data/student_data/student_data_1415_allOffence.csv')

student_data_1314_allOffence = pd.read_excel('../../data/student_data/Student13-14_allOffence.xlsx')
student_data_1314_allOffence=student_data_1314_allOffence[student_data_1314_allOffence['School Name'].str.contains('Boston')]
student_data_1314_allOffence['district']=student_data_1314_allOffence['School Name'].apply(add_districts)
student_data_1314_allOffence.to_csv('../../data/student_data/student_data_1314_allOffence.csv')

student_data_1213_allOffence = pd.read_excel('../../data/student_data/Student12-13_allOffence.xlsx')
student_data_1213_allOffence=student_data_1213_allOffence[student_data_1213_allOffence['School Name'].str.contains('Boston')]
student_data_1213_allOffence['district']=student_data_1213_allOffence['School Name'].apply(add_districts)
student_data_1213_allOffence.to_csv('../../data/student_data/student_data_1213_allOffence.csv')

# %%
##Do not run this code
##Data is unavailable

#This code was used to create csv files

def add_districts(x):
    B3=["KIPP Academy Boston Charter School","Taylor Elementary School","Mildred Avenue K-8","Chittick Elementary School",
    "Young Achievers Science and Math School","Dr. Catherine Ellison-Rosa Parks Early Ed School",
    "Grove Hall Child Development Center","Jubilee Academy Pre-School","Sparks Center","Boston Nature Center",
    "Mattapan Head Start","Necub Day Care","La Ronde De Marie Claire Elc","Tabitha House Day Care","Mattahunt Elementary School"]

    E13=["Boston Teachers Union School","Curley K-8 School","Elc - West Zone","John F Kennedy","Joseph P Manning","Mission Hill School"]

    C11=["Dr. William Henderson Lower","Edward Everett","John Winthrop","Joseph Lee","King K-8","Lee Academy",
    "Mather","O W Holmes","Paul A Dever"]

    for d in B3:
        if d in x and "Boston" in x:
            return "B3"
    
    for d in E13:
        if d in x and "Boston" in x:
            return "E13"

    for d in C11:
        if d in x and "Boston" in x:
            return "C11"

    return "not D4"


student_data_2122_F = pd.read_excel('../../data/student_data/StudentDisciplineF_2122.xlsx')
student_data_2122_F=student_data_2122_F[student_data_2122_F['School Name'].str.contains('Boston')]
student_data_2122_F['district']=student_data_2122_F['School Name'].apply(add_districts)
student_data_2122_F.to_csv('../../data/student_data/student_data_2122_F.csv')

student_data_2021_F = pd.read_excel('../../data/student_data/StudentDisciplineF_2021.xlsx')
student_data_2021_F=student_data_2021_F[student_data_2021_F['School Name'].str.contains('Boston')]
student_data_2021_F['district']=student_data_2021_F['School Name'].apply(add_districts)
student_data_2021_F.to_csv('../../data/student_data/student_data_2021_F.csv')

student_data_1920_F = pd.read_excel('../../data/student_data/StudentDisciplineF_1920.xlsx')
student_data_1920_F=student_data_1920_F[student_data_1920_F['School Name'].str.contains('Boston')]
student_data_1920_F['district']=student_data_1920_F['School Name'].apply(add_districts)
student_data_1920_F.to_csv('../../data/student_data/student_data_1920_F.csv')

student_data_1819_F = pd.read_excel('../../data/student_data/StudentDisciplineF_1819.xlsx')
student_data_1819_F=student_data_1819_F[student_data_1819_F['School Name'].str.contains('Boston')]
student_data_1819_F['district']=student_data_1819_F['School Name'].apply(add_districts)
student_data_1819_F.to_csv('../../data/student_data/student_data_1819_F.csv')

student_data_1718_F = pd.read_excel('../../data/student_data/StudentDisciplineF_1718.xlsx')
student_data_1718_F=student_data_1718_F[student_data_1718_F['School Name'].str.contains('Boston')]
student_data_1718_F['district']=student_data_1718_F['School Name'].apply(add_districts)
student_data_1718_F.to_csv('../../data/student_data/student_data_1718_F.csv')

student_data_1617_F = pd.read_excel('../../data/student_data/StudentDisciplineF_1617.xlsx')
student_data_1617_F=student_data_1617_F[student_data_1617_F['School Name'].str.contains('Boston')]
student_data_1617_F['district']=student_data_1617_F['School Name'].apply(add_districts)
student_data_1617_F.to_csv('../../data/student_data/student_data_1617_F.csv')

student_data_1516_F = pd.read_excel('../../data/student_data/StudentDisciplineF_1516.xlsx')
student_data_1516_F=student_data_1516_F[student_data_1516_F['School Name'].str.contains('Boston')]
student_data_1516_F['district']=student_data_1516_F['School Name'].apply(add_districts)
student_data_1516_F.to_csv('../../data/student_data/student_data_1516_F.csv')

student_data_1415_F = pd.read_excel('../../data/student_data/StudentDisciplineF_1415.xlsx')
student_data_1415_F=student_data_1415_F[student_data_1415_F['School Name'].str.contains('Boston')]
student_data_1415_F['district']=student_data_1415_F['School Name'].apply(add_districts)
student_data_1415_F.to_csv('../../data/student_data/student_data_1415_F.csv')

student_data_1314_F = pd.read_excel('../../data/student_data/StudentDisciplineF_1314.xlsx')
student_data_1314_F=student_data_1314_F[student_data_1314_F['School Name'].str.contains('Boston')]
student_data_1314_F['district']=student_data_1314_F['School Name'].apply(add_districts)
student_data_1314_F.to_csv('../../data/student_data/student_data_1314_F.csv')

student_data_1213_F = pd.read_excel('../../data/student_data/StudentDisciplineF_1213.xlsx')
student_data_1213_F=student_data_1213_F[student_data_1213_F['School Name'].str.contains('Boston')]
student_data_1213_F['district']=student_data_1213_F['School Name'].apply(add_districts)
student_data_1213_F.to_csv('../../data/student_data/student_data_1213_F.csv')

# %% [markdown]
# Plotting the Percentage of students disciplined per district for all 10 years (2012-2022).

# %%
def district_code(x):
    if x=="not D4": return 1
    if x=="B3": return 3
    if x=="C11": return 5
    if x=="E13": return 7


student_data_1213_allOffence=pd.read_csv("../../../data/student_data/student_data_1213_allOffence.csv")
student_data_1213_allOffence["Students"]=student_data_1213_allOffence["Students"].apply(lambda x: int(float(x.strip().replace(",",""))))
student_data_1213_allOffence["district_code"]=student_data_1213_allOffence["district"].apply(district_code)
plt.bar([1.1,3.1,5.1,7.1],
student_data_1213_allOffence.groupby('district_code')['Students Disciplined'].sum()/student_data_1213_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2012-2013')

student_data_1314_allOffence=pd.read_csv("../../../data/student_data/student_data_1314_allOffence.csv")
student_data_1314_allOffence["Students"]=student_data_1314_allOffence["Students"].apply(lambda x: int(float(x.strip().replace(",",""))))
student_data_1314_allOffence["district_code"]=student_data_1314_allOffence["district"].apply(district_code)
plt.bar([1.2,3.2,5.2,7.2],
student_data_1314_allOffence.groupby('district_code')['Students Disciplined'].sum()/student_data_1314_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2013-2014')

student_data_1415_allOffence=pd.read_csv("../../../data/student_data/student_data_1415_allOffence.csv")
student_data_1415_allOffence["Students"]=student_data_1415_allOffence["Students"].apply(lambda x: int(float(x.strip().replace(",",""))))
student_data_1415_allOffence["district_code"]=student_data_1415_allOffence["district"].apply(district_code)
plt.bar([1.3,3.3,5.3,7.3],
student_data_1415_allOffence.groupby('district_code')['Students Disciplined'].sum()/student_data_1415_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2014-2015')

student_data_1516_allOffence=pd.read_csv("../../../data/student_data/student_data_1516_allOffence.csv")
student_data_1516_allOffence["Students"]=student_data_1516_allOffence["Students"].apply(lambda x: int(float(x.strip().replace(",",""))))
student_data_1516_allOffence["district_code"]=student_data_1516_allOffence["district"].apply(district_code)
plt.bar([1.4,3.4,5.4,7.4],
student_data_1516_allOffence.groupby('district_code')['Students Disciplined'].sum()/student_data_1516_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2015-2016')

student_data_1617_allOffence=pd.read_csv("../../../data/student_data/student_data_1617_allOffence.csv")
student_data_1617_allOffence["Students"]=student_data_1617_allOffence["Students"].apply(lambda x: int(float(x.strip().replace(",",""))))
student_data_1617_allOffence["district_code"]=student_data_1617_allOffence["district"].apply(district_code)
plt.bar([1.5,3.5,5.5,7.5],
student_data_1617_allOffence.groupby('district_code')['Students Disciplined'].sum()/student_data_1617_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2016-2017')

student_data_1718_allOffence=pd.read_csv("../../../data/student_data/student_data_1718_allOffence.csv")
student_data_1718_allOffence["Students"]=student_data_1718_allOffence["Students"].apply(lambda x: int(float(x.strip().replace(",",""))))
student_data_1718_allOffence["district_code"]=student_data_1718_allOffence["district"].apply(district_code)
plt.bar([1.6,3.6,5.6,7.6],
student_data_1718_allOffence.groupby('district_code')['Students Disciplined'].sum()/student_data_1718_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2017-2018')

student_data_1819_allOffence=pd.read_csv("../../../data/student_data/student_data_1819_allOffence.csv")
student_data_1819_allOffence["Students"]=student_data_1819_allOffence["Students"].apply(lambda x: int(float(x.strip().replace(",",""))))
student_data_1819_allOffence["district_code"]=student_data_1819_allOffence["district"].apply(district_code)
plt.bar([1.7,3.7,5.7,7.7],
student_data_1819_allOffence.groupby('district_code')['Students Disciplined'].sum()/student_data_1819_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2018-2019')

student_data_1920_allOffence=pd.read_csv("../../../data/student_data/student_data_1920_allOffence.csv")
student_data_1920_allOffence["Students"]=student_data_1920_allOffence["Students"].apply(lambda x: int(float(x.strip().replace(",",""))))
student_data_1920_allOffence["district_code"]=student_data_1920_allOffence["district"].apply(district_code)
plt.bar([1.8,3.8,5.8,7.8],
student_data_1920_allOffence.groupby('district_code')['Students Disciplined'].sum()/student_data_1920_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2019-2020')

student_data_2021_allOffence=pd.read_csv("../../../data/student_data/student_data_2021_allOffence.csv")
student_data_2021_allOffence["Students"]=student_data_2021_allOffence["Students"].apply(lambda x: int(float(x.strip().replace(",",""))))
student_data_2021_allOffence["district_code"]=student_data_2021_allOffence["district"].apply(district_code)
plt.bar([1.9,3.9,5.9,7.9],
student_data_2021_allOffence.groupby('district_code')['Students Disciplined'].sum()/student_data_2021_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2020-2021')

student_data_2122_allOffence=pd.read_csv("../../../data/student_data/student_data_2122_allOffence.csv")
student_data_2122_allOffence["Students"]=student_data_2122_allOffence["Students"].apply(lambda x: int(float(x.strip().replace(",",""))))
student_data_2122_allOffence["district_code"]=student_data_2122_allOffence["district"].apply(district_code)
plt.bar([2,4,6,8],
student_data_2122_allOffence.groupby('district_code')['Students Disciplined'].sum()/student_data_2122_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2021-2022')

plt.title("Percentage of students disciplined per district")
plt.xlabel("Districts")
plt.legend(bbox_to_anchor=(1.2, 1.05))
plt.xticks([1.5,3.5,5.5,7.5], ['not D4', 'B3', 'C11', 'E13'])
plt.show()

# %% [markdown]
# B3: In 2018, the percentage of students getting disciplined in B3 was higher than most other districts. Currently these seems to be a study decline of student disciplines.
#
# C11: The percentage of students getting disciplined in C11 has been increasing from 2018
#
# E13: Does not seem to be following any trend

# %% [markdown]
# .

# %% [markdown]
# Plotting the Number of Students per district for all 10 years (2012-2022).

# %%
plt.bar([1.1,3.1,5.1,7.1],student_data_1213_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2012-2013')

plt.bar([1.2,3.2,5.2,7.2],student_data_1314_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2013-2014')

plt.bar([1.3,3.3,5.3,7.3],student_data_1415_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2014-2015')

plt.bar([1.4,3.4,5.4,7.4],student_data_1516_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2015-2016')

plt.bar([1.5,3.5,5.5,7.5],student_data_1617_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2016-2017')

plt.bar([1.6,3.6,5.6,7.6],student_data_1718_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2017-2018')

plt.bar([1.7,3.7,5.7,7.7],student_data_1819_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2018-2019')

plt.bar([1.8,3.8,5.8,7.8],student_data_1920_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2019-2020')

plt.bar([1.9,3.9,5.9,7.9],student_data_2021_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2020-2021')

plt.bar([2,4,6,8],
student_data_2122_allOffence.groupby('district_code')['Students Disciplined'].sum()/student_data_2122_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2021-2022')

plt.legend(bbox_to_anchor=(1.2, 1.05))
plt.xticks([1.5,3.5,5.5,7.5], ['not D4', 'B3', 'C11', 'E13'])
plt.title("Number of Students per district")
plt.xlabel("Districts")
plt.ylabel("No of students")
plt.grid(axis = 'y',linestyle = '--')
plt.yticks(np.arange(0, 60000, step=5000))
plt.show()

# %% [markdown]
# B3: These is a study increase in the number of students in B3.
#
# C11: Year by year, these is a slight decrease in the number of students in C11 from 2016

# %% [markdown]
# .

# %% [markdown]
# Plotting the Number of Students Disciplined per district for all 10 years (2012-2022).

# %%
plt.bar([1.1,3.1,5.1,7.1],student_data_1213_allOffence.groupby('district_code')['Students Disciplined'].sum(),
0.1, label = '2012-2013')

plt.bar([1.2,3.2,5.2,7.2],student_data_1314_allOffence.groupby('district_code')['Students Disciplined'].sum(),
0.1, label = '2013-2014')

plt.bar([1.3,3.3,5.3,7.3],student_data_1415_allOffence.groupby('district_code')['Students Disciplined'].sum(),
0.1, label = '2014-2015')

plt.bar([1.4,3.4,5.4,7.4],student_data_1516_allOffence.groupby('district_code')['Students Disciplined'].sum(),
0.1, label = '2015-2016')

plt.bar([1.5,3.5,5.5,7.5],student_data_1617_allOffence.groupby('district_code')['Students Disciplined'].sum(),
0.1, label = '2016-2017')

plt.bar([1.6,3.6,5.6,7.6],student_data_1718_allOffence.groupby('district_code')['Students Disciplined'].sum(),
0.1, label = '2017-2018')

plt.bar([1.7,3.7,5.7,7.7],student_data_1819_allOffence.groupby('district_code')['Students Disciplined'].sum(),
0.1, label = '2018-2019')

plt.bar([1.8,3.8,5.8,7.8],student_data_1920_allOffence.groupby('district_code')['Students Disciplined'].sum(),
0.1, label = '2019-2020')

plt.bar([1.9,3.9,5.9,7.9],student_data_2021_allOffence.groupby('district_code')['Students Disciplined'].sum(),
0.1, label = '2020-2021')

plt.bar([2,4,6,8],
student_data_2122_allOffence.groupby('district_code')['Students Disciplined'].sum()/student_data_2122_allOffence.groupby('district_code')['Students'].sum(),
0.1, label = '2021-2022')

plt.legend(bbox_to_anchor=(1.2, 1.05))
plt.xticks([1.5,3.5,5.5,7.5], ['not D4', 'B3', 'C11', 'E13'])
plt.title("Number of Students Disciplined per district")
plt.xlabel("Districts")
plt.ylabel("No of students")
#plt.grid(axis = 'y',linestyle = '--')
#plt.yticks(np.arange(0, 60000, step=5000))
plt.show()

# %% [markdown]
# Same obserations as "Percentage of students disciplined per district"

# %% [markdown]
#
#
#  .

# %% [markdown]
# Student Discipline Data for Felony conviction or complaint

# %%
student_data_1213_F=pd.read_csv("../../../data/student_data/student_data_1213_F.csv")
student_data_1213_F["Students"]=student_data_1213_F["Students"].apply(lambda x: int(float(x.strip().replace(",",""))))
student_data_1213_F["district_code"]=student_data_1213_F["district"].apply(district_code)

student_data_1314_F=pd.read_csv("../../../data/student_data/student_data_1314_F.csv")
student_data_1314_F["Students"]=student_data_1314_F["Students"].apply(lambda x: int(float(str(x).strip().replace(",",""))))
student_data_1314_F["district_code"]=student_data_1314_F["district"].apply(district_code)

student_data_1415_F=pd.read_csv("../../../data/student_data/student_data_1415_F.csv")
student_data_1415_F["Students"]=student_data_1415_F["Students"].apply(lambda x: int(float(x.strip().replace(",",""))))
student_data_1415_F["district_code"]=student_data_1415_F["district"].apply(district_code)

student_data_1516_F=pd.read_csv("../../../data/student_data/student_data_1516_F.csv")
student_data_1516_F["Students"]=student_data_1516_F["Students"].apply(lambda x: int(float(str(x).strip().replace(",",""))))
student_data_1516_F["district_code"]=student_data_1516_F["district"].apply(district_code)

student_data_1617_F=pd.read_csv("../../../data/student_data/student_data_1617_F.csv")
student_data_1617_F["Students"]=student_data_1617_F["Students"].apply(lambda x: int(float(x.strip().replace(",",""))))
student_data_1617_F["district_code"]=student_data_1617_F["district"].apply(district_code)

student_data_1718_F=pd.read_csv("../../../data/student_data/student_data_1718_F.csv")
student_data_1718_F["Students"]=student_data_1718_F["Students"].apply(lambda x: int(float(str(x).strip().replace(",",""))))
student_data_1718_F["district_code"]=student_data_1718_F["district"].apply(district_code)

student_data_1819_F=pd.read_csv("../../../data/student_data/student_data_1819_F.csv")
student_data_1819_F["Students"]=student_data_1819_F["Students"].apply(lambda x: int(float(str(x).strip().replace(",",""))))
student_data_1819_F["district_code"]=student_data_1819_F["district"].apply(district_code)

student_data_1920_F=pd.read_csv("../../../data/student_data/student_data_1920_F.csv")
student_data_1920_F["Students"]=student_data_1920_F["Students"].apply(lambda x: int(float(str(x).strip().replace(",",""))))
student_data_1920_F["district_code"]=student_data_1920_F["district"].apply(district_code)

student_data_2021_F=pd.read_csv("../../../data/student_data/student_data_2021_F.csv")
student_data_2021_F["Students"]=student_data_2021_F["Students"].apply(lambda x: int(float(str(x).strip().replace(",",""))))
student_data_2021_F["district_code"]=student_data_2021_F["district"].apply(district_code)

student_data_2122_F=pd.read_csv("../../../data/student_data/student_data_2122_F.csv")
student_data_2122_F["Students"]=student_data_2122_F["Students"].apply(lambda x: int(float(str(x).strip().replace(",",""))))
student_data_2122_F["district_code"]=student_data_2122_F["district"].apply(district_code)

# %%
def district_code(x):
    if x=="not D4": return 1
    if x=="B3": return 3
    if x=="C11": return 5
    if x=="E13": return 7


index=[x+0.1 for x in student_data_1213_F['district_code'].unique()]
plt.bar(index,
student_data_1213_F.groupby('district_code')['Students Disciplined'].sum()/student_data_1213_F.groupby('district_code')['Students'].sum(),
0.1, label = '2012-2013')

index=[x+0.2 for x in student_data_1314_F['district_code'].unique()]
plt.bar(index,
student_data_1314_F.groupby('district_code')['Students Disciplined'].sum()/student_data_1314_F.groupby('district_code')['Students'].sum(),
0.1, label = '2013-2014')

index=[x+0.3 for x in student_data_1415_F['district_code'].unique()]
plt.bar(index,
student_data_1415_F.groupby('district_code')['Students Disciplined'].sum()/student_data_1415_F.groupby('district_code')['Students'].sum(),
0.1, label = '2014-2015')

index=[x+0.4 for x in student_data_1516_F['district_code'].unique()]
plt.bar(index,
student_data_1516_F.groupby('district_code')['Students Disciplined'].sum()/student_data_1516_F.groupby('district_code')['Students'].sum(),
0.1, label = '2015-2016')

index=[x+0.5 for x in student_data_1617_F['district_code'].unique()]
plt.bar(index,
student_data_1617_F.groupby('district_code')['Students Disciplined'].sum()/student_data_1617_F.groupby('district_code')['Students'].sum(),
0.1, label = '2016-2017')

index=[x+0.6 for x in student_data_1718_F['district_code'].unique()]
plt.bar(index,
student_data_1718_F.groupby('district_code')['Students Disciplined'].sum()/student_data_1718_F.groupby('district_code')['Students'].sum(),
0.1, label = '2017-2018')

index=[x+0.7 for x in student_data_1819_F['district_code'].unique()]
plt.bar(index,
student_data_1819_F.groupby('district_code')['Students Disciplined'].sum()/student_data_1819_F.groupby('district_code')['Students'].sum(),
0.1, label = '2018-2019')

index=[x+0.8 for x in student_data_1920_F['district_code'].unique()]
plt.bar(index,
student_data_1920_F.groupby('district_code')['Students Disciplined'].sum()/student_data_1920_F.groupby('district_code')['Students'].sum(),
0.1, label = '2019-2020')

index=[x+0.9 for x in student_data_2021_F['district_code'].unique()]
plt.bar(index,
student_data_2021_F.groupby('district_code')['Students Disciplined'].sum()/student_data_2021_F.groupby('district_code')['Students'].sum(),
0.1, label = '2020-2021')

index=[x+1 for x in student_data_2122_F['district_code'].unique()]
plt.bar(index,
student_data_2122_F.groupby('district_code')['Students Disciplined'].sum()/student_data_2122_F.groupby('district_code')['Students'].sum(),
0.1, label = '2021-2022')

plt.title("Percentage of students disciplined for Felony per district")
plt.xlabel("Districts")
plt.legend(bbox_to_anchor=(1.2, 1.05))
plt.xticks([1.5,3.5,5.5,7.5], ['not D4', 'B3', 'C11', 'E13'])
plt.show()
