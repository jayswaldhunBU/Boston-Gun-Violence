# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

Traffic_df = pd.read_csv("../data/BTDTrafficData.csv")
Traffic_df
# Out:
#                 Archive Date                            Associated Streets  \
# 0     03/02/2020 03:32:58 PM  FALMOUTH ST, MASSACHUSETTS AVE, WESTLAND AVE
# 1     03/02/2020 03:32:58 PM             TREMONT ST, WINTER PLACE, PARK ST
# 2     03/02/2020 03:32:58 PM                           D ST, WEST FIRST ST
# 3     03/02/2020 03:32:58 PM                           EAST FIFTH ST, I ST
# 4     03/02/2020 03:32:58 PM                       CHARLES ST, PINCKNEY ST
# ...                      ...                                           ...
# 5065  01/17/2019 07:00:00 PM                       CAMBRIDGE ST, GORDON ST
# 5066  01/17/2019 07:00:00 PM                           GUEST ST, MARKET ST
# 5067  01/17/2019 07:00:00 PM                   DORCHESTER AVE, RICHMOND ST
# 5068  01/22/2019 07:00:00 PM                                           NaN
# 5069  01/22/2019 07:00:00 PM                                           NaN
#
#      Collection Date Data Type  Intersection Number Neighborhood Code  \
# 0         10-29-2019       NaN                 93.0     BOSTON PROPER
# 1         10-01-2019       NaN                  8.0     BOSTON PROPER
# 2         11-21-2019       NaN               1484.0      SOUTH BOSTON
# 3         11-21-2019       NaN               1462.0      SOUTH BOSTON
# 4         10-02-2019       NaN                142.0     BOSTON PROPER
# ...              ...       ...                  ...               ...
# 5065      11-01-2018       NaN                449.0                BR
# 5066      11-01-2018       NaN               3112.0                BR
# 5067      11-01-2018       NaN                721.0                DR
# 5068      11-01-2018    VOLUME                  NaN     BOSTON PROPER
# 5069      10-31-2018    VOLUME                  NaN     BOSTON PROPER
#
#                                      Original File Name  Site Location  \
# 0     \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
# 1     \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
# 2     \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
# 3     \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
# 4     \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
# ...                                                 ...            ...
# 5065  \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
# 5066  \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
# 5067  \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
# 5068  \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...          454.0
# 5069  \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...          264.0
#
#      Street Name Study Period                    Study Type
# 0            NaN     12 HOURS        TURNING MOVEMENT COUNT
# 1            NaN     12 HOURS        TURNING MOVEMENT COUNT
# 2            NaN     12 HOURS        TURNING MOVEMENT COUNT
# 3            NaN     12 HOURS        TURNING MOVEMENT COUNT
# 4            NaN     12 HOURS        TURNING MOVEMENT COUNT
# ...          ...          ...                           ...
# 5065         NaN     11 HOURS        TURNING MOVEMENT COUNT
# 5066         NaN     11 HOURS        TURNING MOVEMENT COUNT
# 5067         NaN     11 HOURS        TURNING MOVEMENT COUNT
# 5068   BEACON ST     24 HOURS  AUTOMATED TRAFFICE RECORDING
# 5069   BEACON ST     24 HOURS  AUTOMATED TRAFFICE RECORDING
#
# [5070 rows x 11 columns]

# %%
print(Traffic_df['Neighborhood Code'].unique())
# Out:
# ['BOSTON PROPER' 'SOUTH BOSTON' 'DORCHESTER' 'WEST ROXBURY' 'EAST BOSTON'
#  'DO' 'ROXBURY' 'ALLSTON BRIGHTON' 'CHARLESTOWN' 'DR' 'HYDE PARK' 'BR'
#  ' WR' 'BRI' 'RO' 'DOR' 'AL' 'X' nan]

# %%
values_to_drop = [' WR','DO', 'DR', 'BR', 'BRI', 'RO', 'DOR', 'AL', 'X']

# if Traffic_df['Neighborhood Code'].isin(values_to_drop).any():
#     Traffic_df.drop(columns='Neighborhood Code', inplace=True)

rows_to_drop = Traffic_df[Traffic_df['Neighborhood Code'].isin(values_to_drop)].index

Traffic_df.dropna(subset=['Neighborhood Code'], inplace=True)
Traffic_df.drop(index=rows_to_drop, inplace=True)

print(Traffic_df['Neighborhood Code'].unique())
# Out:
# ['BOSTON PROPER' 'SOUTH BOSTON' 'DORCHESTER' 'WEST ROXBURY' 'EAST BOSTON'
#  'ROXBURY' 'ALLSTON BRIGHTON' 'CHARLESTOWN' 'HYDE PARK']

# %%
other_values_to_drop = ['BOSTON PROPER', 'SOUTH BOSTON', 'EAST BOSTON', 'ALLSTON BRIGHTON', 'CHARLESTOWN']
other_rows_to_drop = Traffic_df[Traffic_df['Neighborhood Code'].isin(other_values_to_drop)].index

Traffic_df.drop(index=other_rows_to_drop, inplace=True)
print(Traffic_df['Neighborhood Code'].unique())
# Out:
# ['DORCHESTER' 'WEST ROXBURY' 'ROXBURY' 'HYDE PARK']

# %%
print(Traffic_df.isna().sum())
# Out:
# Archive Date              0
# Associated Streets      942
# Collection Date           0
# Data Type              1221
# Intersection Number     943
# Neighborhood Code         0
# Original File Name        0
# Site Location          1221
# Street Name            1221
# Study Period              0
# Study Type                0
# dtype: int64

# %%
Traffic_df.dropna()
print(Traffic_df.shape)
print(Traffic_df.isna().sum())
# Out:
# (2164, 11)
# Archive Date              0
# Associated Streets      942
# Collection Date           0
# Data Type              1221
# Intersection Number     943
# Neighborhood Code         0
# Original File Name        0
# Site Location          1221
# Street Name            1221
# Study Period              0
# Study Type                0
# dtype: int64

# %%
# read the BTDTrafficData.csv file into a pandas dataframe
Traffic_df = pd.read_csv("../data/BTDTrafficData.csv")

values_to_drop = [' WR','DO', 'DR', 'BR', 'BRI', 'RO', 'DOR', 'AL', 'X']

# if Traffic_df['Neighborhood Code'].isin(values_to_drop).any():
#     Traffic_df.drop(columns='Neighborhood Code', inplace=True)

rows_to_drop = Traffic_df[Traffic_df['Neighborhood Code'].isin(values_to_drop)].index

Traffic_df.dropna(subset=['Neighborhood Code'], inplace=True)
Traffic_df.drop(index=rows_to_drop, inplace=True)

other_values_to_drop = ['BOSTON PROPER', 'SOUTH BOSTON', 'EAST BOSTON', 'ALLSTON BRIGHTON', 'CHARLESTOWN', 'WEST ROXBURY', 'HYDE PARK']
other_rows_to_drop = Traffic_df[Traffic_df['Neighborhood Code'].isin(other_values_to_drop)].index

Traffic_df.drop(index=other_rows_to_drop, inplace=True)

print(Traffic_df['Neighborhood Code'].unique())

# count the number of streets in each cell of the "Associated Streets" column
street_counts = Traffic_df['Associated Streets'].str.count(',') + 1

# add the "Street Count" column to the dataframe
Traffic_df['Street Count'] = street_counts

Traffic_df
# Out:
# ['DORCHESTER' 'ROXBURY']
#                 Archive Date                          Associated Streets  \
# 5     03/02/2020 03:32:58 PM  EAST COTTAGE ST, HUMPHREYS ST, NORFOLK AVE
# 9     03/02/2020 03:32:58 PM                      MILTON AVE, NORFOLK ST
# 59    06/16/2019 08:00:00 PM                   HUNTINGTON AVE, MUSEUM RD
# 75    12/20/2013 07:00:00 PM                       CENTRE ST, ROXBURY ST
# 79    01/02/2014 07:00:00 PM                         MAPLE ST, SEAVER ST
# ...                      ...                                         ...
# 5049  12/10/2018 07:00:00 PM                                         NaN
# 5050  12/10/2018 07:00:00 PM                                         NaN
# 5057  12/10/2018 07:00:00 PM                                         NaN
# 5058  12/10/2018 07:00:00 PM                                         NaN
# 5062  01/15/2019 07:00:00 PM        HARRISON AVE, PALMER ST, SHABAZZ WAY
#
#      Collection Date Data Type  Intersection Number Neighborhood Code  \
# 5         11-21-2019       NaN               2413.0        DORCHESTER
# 9         02-25-2020       NaN               2646.0        DORCHESTER
# 59        01-03-2019       NaN               3080.0           ROXBURY
# 75        12-04-2012       NaN                195.0           ROXBURY
# 79        09-25-2007       NaN                981.0           ROXBURY
# ...              ...       ...                  ...               ...
# 5049      04-23-2018    VOLUME                  NaN        DORCHESTER
# 5050      04-24-2018    VOLUME                  NaN        DORCHESTER
# 5057      09-27-2018       XXX                  NaN        DORCHESTER
# 5058      04-24-2018     SPEED                  NaN        DORCHESTER
# 5062      12-18-2018       NaN               2606.0           ROXBURY
#
#                                      Original File Name  Site Location  \
# 5     \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
# 9     \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
# 59    \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
# 75    \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
# 79    \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
# ...                                                 ...            ...
# 5049  \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...           42.0
# 5050  \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...          178.0
# 5057  \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...         1868.0
# 5058  \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...          178.0
# 5062  \\CH-NAS\SCERISISD\BTD_SCERIS_DOCS\BTD_TRAFFIC...            NaN
#
#          Street Name Study Period                    Study Type  Street Count
# 5                NaN     11 HOURS        TURNING MOVEMENT COUNT           3.0
# 9                NaN     11 HOURS        TURNING MOVEMENT COUNT           2.0
# 59               NaN     11 HOURS                           PMC           2.0
# 75               NaN      4 HOURS        TURNING MOVEMENT COUNT           2.0
# 79               NaN     12 HOURS        TURNING MOVEMENT COUNT           2.0
# ...              ...          ...                           ...           ...
# 5049    INTERVALE ST     48 HOURS  AUTOMATED TRAFFICE RECORDING           NaN
# 5050     MAGNOLIA ST     48 HOURS  AUTOMATED TRAFFICE RECORDING           NaN
# 5057  DORCHESTER AVE     48 HOURS  AUTOMATED TRAFFICE RECORDING           NaN
# 5058     MAGNOLIA ST     48 HOURS  AUTOMATED TRAFFICE RECORDING           NaN
# 5062             NaN     11 HOURS                           PMC           3.0
#
# [1489 rows x 12 columns]

# %%
print(Traffic_df['Associated Streets'].unique())
# Out:
# ['EAST COTTAGE ST, HUMPHREYS ST, NORFOLK AVE' 'MILTON AVE, NORFOLK ST'
#  'HUNTINGTON AVE, MUSEUM RD' 'CENTRE ST, ROXBURY ST' 'MAPLE ST, SEAVER ST'
#  'MALCOLM X BLVD, ROXBURY ST CONNECTOR, SHAWMUT AVE'
#  'MELVILLE AVE, HOOPER ST' 'ELM HILL AVE, HOWLAND ST' nan
#  'MELNEA CASS BLVD, WASHINGTON ST' 'QUINCY ST, CEYLON ST'
#  'SOUTH HUNTINGTON AVE, VETERANS HOSPITAL'
#  'ADAMS ST, CENTRE ST, ELMDALE ST'
#  'BLUE HILL AVE, FESSENDEN ST, WELLINGTON HILL ST'
#  'CALUMET ST, FRANCIS ST, HUNTINGTON AVE, TREMONT ST'
#  'MASSACHUSETTS AVE, MELNEA CASS BLVD, SOUTHAMPTON ST'
#  'BROADWAY BRIDGE, DORCHESTER AVE, WEST BROADWAY'
#  'ALBAN ST, TALBOT AVE, WELLES AVE' 'CLIFFORD ST, DALE ST, WARREN ST'
#  'NEW ENGLAND AVE, NORWELL ST, TALBOT AVE'
#  'HUMBOLDT AVE, MARTIN LUTHER KING JR BLVD' 'DUDLEY ST, HARRISON AVE'
#  'COLUMBIA RD, DUDLEY ST, STOUGHTON ST' 'DUDLEY ST, HAMPDEN ST'
#  'COLUMBUS AVE @ #2044' 'DORCHESTER AVE, DORSET ST, LOCUST ST'
#  'FRANCIS ST, VINING ST'
#  'MALCOLM X BLVD, ROXBURY ST CONNECTOR, SHAWMUT AVE EXT'
#  'EAST LENOX ST, LENOX ST, WASHINGTON ST' '51 GENEVA AVE'
#  'CENTRE ST, HEWLETT ST' 'D ST, OLD COLONY AVE'
#  'ST ALPHONSUS ST, TREMONT ST' 'COLUMBUS AVE, WASHINGTON ST'
#  'DUDLEY ST, EAST COTTAGE ST, WEST COTTAGE ST' 'BLUE HILL AVE, FAIRWAY ST'
#  'BLUE HILL AVE, WOODROW AVE' 'DORCHESTER ST, OLD COLONY AVE'
#  'BRUNSWICK ST, WARREN ST' 'GEORGE ST, MAGAZINE ST'
#  'DORCHESTER AVE, EAST ST, FREEPORT ST' 'INTERVALE ST, WARREN ST'
#  'COLUMBUS AVE, MELNEA CASS BLVD' 'ASHMONT ST, TRAIN ST'
#  'GENEVA AVE, NORMANDY ST' 'HUMBOLDT AVE, WYOMING ST'
#  'COLUMBUS AVE, SEAVER ST, WALNUT AVE' 'GREENBRIER ST, PARK ST'
#  'MALCOLM X BLVD, ROXBURY ST' 'BLUE HILL AVE, CLIFFORD ST, JULIAN ST'
#  'ADAMS ST, OAKTON ST, HELENA RD' 'DALE ST, WALNUT AVE'
#  'ELM HILL AVE, RUTHVEN ST' 'ADAMS ST, DIX ST'
#  'AUTUMN ST, LONGWOOD AVE, NESSEL WAY' 'BROMLEY ST, NEW HEATH ST'
#  'OAK ST, WALK HILL ST' 'MELNEA CASS BLVD, TREMONT ST'
#  'DORCHESTER AVE, HANCOCK ST, HOYT ST'
#  'CENTRE ST, ESTRELLA ST, SHOPPING PLAZA' 'BOUTWELL ST, TRAIN ST'
#  'COLUMBIA RD, HANCOCK ST' 'NIGHTINGALE ST, TALBOT AVE'
#  'ALLEN ST, ROWE ST' 'HARVARD ST, WALK HILL ST' 'BOWDOIN ST, GENEVA AVE'
#  'BURGESS ST, DUDLEY ST, FOLSOM ST' 'CEDAR ST, WASHINGTON ST'
#  'TOWNSEND ST, WALNUT AVE' 'HUMBOLDT AVE, WAUMBECK ST'
#  'BISMARCK ST, BROCKTON ST, CUMMINS HWY' 'ROCKLAND ST, WALNUT AVE'
#  'KERR WAY, MELNEA CASS BLVD' 'HUNTINGTON AVE, LOUIS PRANG ST, RUGGLES ST'
#  'BIRD ST, COLUMBIA RD' 'BLUE HILL AVE, DUDLEY ST, MAGAZINE ST'
#  'FOTTLER RD, WALK HILL ST' 'CHESTERTON ST, MASS AVE'
#  'BOSTON ST, COLUMBIA RD, EAST COTTAGE ST, MASS AVE'
#  'MASS AVE, SOUTH BAY MALL ENTRANCE'
#  'ALLSTATE RD, MASS AVE, NSTAR DRIVEWAY'
#  'BRADSTON ST, MASS AVE, SOUTHAMPTON ST' 'BLUE HILL AVE, CASTLEGATE RD'
#  'NORFOLK AVE, SHIRLEY ST' 'ADAMS ST, DORCHESTER AVE, WASHINGTON ST'
#  'CUMMINS HWY, HARVARD ST, WOOD AVE' 'HANCOCK ST, PLEASANT ST'
#  'HUMBOLDT AVE, WALNUT AVE' 'BLUE HILL AVE, WARREN ST'
#  'BLUE HILL AVE, CHENEY ST, WASHINGTON ST'
#  'BRINTON ST, MARCELLA ST, WASHINGTON ST'
#  'DALE ST, OAKLAND ST, WASHINGTON ST' 'BABSON ST, BLUE HILL AVE'
#  'EUSTIS ST, WASHINGTON ST, WILLIAMS ST' 'HARRISON AVE, NORTHAMPTON ST'
#  'BOSTON ST, COLUMBIA RD, MASSACGUSETTS AVE' 'COBDEN ST, WASHINGTON ST'
#  'PARISH ST, WINTER ST' 'ASHMONT ST, WASHINGTON ST'
#  'BLUE HILL AVE, QUINCY ST' 'NORMANDY ST, SEAVER ST'
#  'MASSACHUSETTS AVE, MELNEA CASS BLVD, SOUTHAMPTON ST '
#  'DUNBAR AVE, ROSLIN ST, WASHINGTON ST' 'PARK ST, WASHINGTON ST'
#  'MAGAZINE ST, NORFOLK AVE' 'HARVARD ST, NORWELL ST'
#  'MASS AVE, PROCTOR ST' 'ADAMS ST, EAST ST, WINTER ST'
#  'DORCHESTER AVE, VALLEY RD'
#  "NEPONSET AVE, POPE'S HILL ST, SOUTH MONROE TERR"
#  'NORFOLK ST, WOODROW AVE' 'BOWDOIN ST, QUINCY ST' 'ADAMS ST, ASHMONT ST'
#  'CLAPP ST, MASS AVE' 'BLACKFAN CIRCLE, LONGWOOD AVE'
#  'COPELAND ST, WARREN ST, WAVERLY ST' 'HARRISON AVE, WARREN ST'
#  'BABSON ST, NORFOLK ST' 'BOWDOIN ST, HAMILTON ST'
#  'MASS AVE, POMPEII ST, THEODORE GLYNN WAY' 'GERARD ST, MASS AVE'
#  'BEECHCROFT ST, FANEUIL ST' 'ADAMS ST, KING ST'
#  'MAYFIELD ST, PLEASANT ST' 'ISLAND ST, MASS AVE, FIRE STATION DRIVEWAY'
#  'MASS AVE, MELNEA CASS BLVD' 'MASS AVE, PEIRSON ST'
#  'BRINSLEY ST, COLUMBIA RD, GENEVA AVE' 'COLUMBIA RD, WASHINGTON ST'
#  'PLEASANT ST, HINCKLEY ST' 'LONGWOOD AVE, RIVERWAY'
#  'CUMMINS HWY, GREENFIELD RD' 'WALNUT ST, OAKMAN ST' 'RIVER ST, TEMPLE ST'
#  'BLACKFAN CIR, LONGWOOD AVE' 'BROOKLINE AVE, SHORT ST'
#  'HUNTINGTON AVE, WIGGLESWORTH ST'
#  'HUNTINGTON AVE, MISSION ST, ST ALBANS RD' 'HUNTINGTON AVE, OPERA PL'
#  'RIVERWAY, RIVERWAY CONNECTOR' 'EVANS WAY, FENWAY, LOUIS PRANG ST'
#  'DRUMMOND ST, ERIE ST, GLENWAY ST' 'MASS AVE, NEWMARKET SQ, SHIRLEY ST'
#  'LITHGOW ST, TALBOT AVE' 'MELNEA CASS BLVD, SHAMUT AVE'
#  'KEARSARGE AVE, WARREN ST @ BOYS CLUB' 'BLUE HILL AVE, SEAVER ST'
#  'BLUE HILL AVE, HARVARD ST' 'BLUE HILL AVE, HARVARD ST, TALBOT AVE'
#  'DEWITT DR, RUGGLES ST' 'HAMPDEN ST, MELNEA CASS BLVD'
#  'LONGWOOD AVE, PILGRIM RD' 'HIGHLAND ST, MILLMONT ST'
#  'WARREN ST, CLIFFORD ST, DALE ST' 'KING ST, MALCOLM X BLVD'
#  'BROOKLINE AVE, LONGWOOD AVE' 'COLUMBUS AVE, WASHINGTON ST, ATHERTON ST'
#  'FISHER AVE, PARKER ST' 'BINNEY ST, LONGWOOD AVE'
#  'EVANS WAY, HUNTINGTON AVE' 'FENWOOD RD, HUNTINGTON AVE'
#  'BROOKLINE AVE, RIVERWAY' 'MALCOLM X BLVD, ROXBURY ST, SHAWMUT AVE'
#  'HUMBOLDT AVE, RUTHVEN ST' 'ELM HILL AVE, RUTHVEN'
#  'AMERICAN LEGION HWY, FRANKLIN HILL AVE' 'HEMENWAY ST, WESTLAND AVE'
#  'FORSYTH WAY, HUNGTINGTON AVE, PARKER ST' 'HARVARD ST, WALES ST'
#  'BROOKLINE AVE, FRANCIS ST' 'BELLEVUE ST, COLUMBIA RD, GLENDALE ST'
#  'COLUMBIA RD, DAVERN AVE, HANCOCK ST' 'COLUMBIA RD, SEAVER ST'
#  'GRANITE AVE, MILTON ST' 'COLUMBIA RD, QUINCY ST'
#  'BLACKFAN CIR, BLACKFAN ST, LONGWOOD AVE'
#  'BLUE HILL AVE, GLEN LN, GLENWAY ST' 'ALLSTATE RD, MASSACHUSETTS AVE'
#  'ASHMONT ST, FREEPORT ST, NEPONSET AVE' 'HUNTINGTON AVE, LONGWOOD AVE'
#  ' HUNGTINGTON AVE, PARKER HILL AVE, MISSION PARK DR'
#  'BLUE HILL AVE, COLUMBIA RD, FRANKLIN PARK RD'
#  'COLUMBIA RD, DORCHESTER AVE'
#  'COLUMBIA RD, RUSSELL ELEMENTARY SCHOOL, POND ST'
#  'GRANITE AVE, HILL TOP ST' 'BLUE HILL AVE, GLENWAY ST, GLEN LN'
#  'CEYLON ST, COLUMBIA RD, COLUMBIA TERRACE' 'BINNEY ST, FRANCIS ST'
#  'MARTIN LUTHER KING JR BLVD, WALNUT AVE'
#  'HUNTINGTON AVE, SOUTH HUNTINGTON AVE'
#  'HUNTINGTON AVE, MISSION PARK DR, PARKER HILL AVE'
#  'BLUE HILL AVE, MORELAND ST' 'VERNON ST, WASHINGTON ST'
#  'HUMBOLDT AVE, TOWNSEND ST' 'CUSHING AVE, JEROME ST'
#  'ISLAND ST, MASSACHUSETTS AVE' 'MASS AVE, CHESTERTON ST'
#  'PARKER ST, RUGGLES ST' 'MASS AVE, SHIRLEY ST, NEWMARKET SQ'
#  'MELNEA CASS BLVD, SHAWMUT AVE' 'BOWDOIN ST, HARVARD ST, WASHINGTON ST'
#  'MASS AVE, RUSFIELD ST' 'HUMBOLDT AVE, MARTIN LUTHER KING JR. BLVD'
#  'CUNARD ST, TREMONT ST' 'ANNABEL ST, COLUMBIA RD, HOLDEN ST'
#  'PLEASANT ST, VICTORIA ST' 'DUDLEY ST, MALCOLM X BLVD, WASHINGTON ST'
#  'CRAWFORD ST, HUMBOLDT AVE' 'NEPONSET AVE, VICTORY RD'
#  'BAILEY ST, DORCHESTER AVE, ASHMONT MBTA BUSWAY'
#  'BLUE HILL AVE, BABSON ST' 'HAROLD ST, ABBOTSFORD ST'
#  'BLUE HILL AVE, REGIS RD' 'NEW ENGLAND AVE, NORFOLK ST, WOODROW AVE'
#  'HUNTINGTON AVE (S RDWY), OPERA PL' 'TOWNSEND ST, WASHINGTON ST'
#  'GLENWAY ST, HARVARD ST, WARNER ST' 'QUINCY ST, TOWNSEND ST, WARREN ST'
#  'MAGAZINE ST, MASS AVE' 'CHARLES ST, GENEVA AVE, WALDECK ST'
#  'MLK BVD, WARREN ST' 'LEON ST, RUGGLES ST'
#  'BALSAM RD, BLUE HILL AVE, JOHNSTON RD' 'HUNTINGTON AVE, WARD ST'
#  'HEATH ST, SOUTH HUNTINGTON AVE' 'MELVILLE AVE, UPLAND AVE'
#  'MARTIN LUTHER KING JR BLVD, WARREN ST' 'DIMOCK ST, WASHINGTON ST'
#  'GURNEY ST, PARKER ST, SMITH ST'
#  'BLUE HILL AVE, WESTVIEW ST, STRATTON ST'
#  'BALSAM ST, BLUE HILL AVE, JOHNSTON RD' 'DORCHESTER AVE, PEARL ST'
#  'EDGERLY RD, #60' 'CLEARWATER DR, MARYKNOLL ST' 'MLK BLVD, WARREN ST'
#  'AMERICAN LEGION HWY, BLUE HILL AVE' "NEPONSET AVE, POPE'S HILL ST"
#  'DEERING RD, HARVARD ST' 'MORTON ST, OLD MORTON ST, PLEASANT HILL AVE'
#  'MORELAND ST, REGENT ST, WARREN ST' 'NEPONSET AVE, KING ST'
#  'BLUE HILL AVE, WAVERLY ST' 'CENTRE ST, SAMOSET ST'
#  'WALNUT AVE, ROCKLAND ST' 'DUDLEY ST, WARREN ST'
#  'BLUE HILL AVE, MORTON ST' 'FORSYTH ST, HUNTINGTON AVE'
#  'COLUMBIA RD, DEVON ST' 'HANNON ST, NORFOLK ST, WILLOWWOOD ST'
#  'BOWDOIN AVE, BULLARD ST' 'COLUMBIA RD, GENEVA AVE'
#  'SOUTHAMPTON ST, THEODORE GLYNN WAY, TOPEKA ST' 'LONGWOOD AVE, RIVERWAYY'
#  'FORSYTH WAY, HUNTINGTON AVE, PARKER ST' 'HANCOCK ST, TRULL ST'
#  'WESTERN AVE, ANTWERP ST' 'HARVARD ST, NORWELL SR'
#  'RIVER ST, WASHINGTON ST' 'BELLFLOWER ST, BOSTON ST'
#  'BLUE HILL AVE, STRATTON ST, WESTVIEW ST' 'COLUMBIA RD, HANCOCK'
#  'BROOKLINE AVE, DEACONESS ST, JIMMY FUND WAY' 'GENEVA AVE, OLNEY ST'
#  'COLUMBIA RD, MIDDLE SCHOOL DRIVEWAY, WYOLA PL' 'BOYLSTON ST, ROSS WAY'
#  'BROOKLINE AVE, FENWAY, RIVERWAY' 'CLEARWATER DR, PAULA RD'
#  'ADAMS ST, DUDLEY ST' 'PARKER ST, PARKER HILL ST' 'PARKER ST, PRENTIS ST'
#  'MARTIN LUTHER KING BLVD, VALENTINE ST, WASHINGTON ST'
#  'MORTON ST, RICHMOND ST, WASHINGTON ST' 'HARRISON AVE, MELNEA CASS BLVD'
#  "BLACKFAN CIR, CHILDREN'S HOSPITAL, LONGWOOD AVE"
#  'SAVIN HILL AVE, SYDNEY ST' 'BLUE HILL AVE, INTERVALE ST'
#  'MARTIN LUTHER KING JR BLVD, VALENTINE ST, WASHINGTON ST'
#  'MASS AVE, CLAPP ST' 'RIVER ST, STANDARD ST'
#  'MALCOLM X BLVD, WASHINGTON ST' 'CEYLON ST, COLUMBIA TERR, COLUMBIA RD'
#  'DORCHESTER AVE, LINDEN ST' 'DORCHESTER AVE, GIBSON ST'
#  'DORCHESTER AVE, LINCOLN ST, FAULKNER ST' 'ADAMS ST, PARK ST'
#  'DORCHESTER AVE, ST MARKS CHURCH' 'SAVIN HILL AVE, OLD COLONY TERR'
#  'WARREN ST, SHOPPING CTR DRIVEWAY' 'ELM HILL AVE, WARREN ST,WAUMBECK ST'
#  'ADAMS ST, NEPONSET AVE, PARKMAN ST' 'CENTRE ST, DORCHESTER AVE'
#  'ADAMS ST, DORCHESTER AVE' 'DORCHESTER AVE, SAVIN HILL AVE'
#  'CEDAR ST, CENTRE ST, FORT AVE' 'BISHOP JOE SMITH WAY, GENEVA AVE'
#  'BLUE HILL AVE, GOODALE RD, WOOLSON ST' 'RECTOR RD, RIVER ST'
#  'RUGGLES ST, MBTA BUS DR' 'PRENTISS ST, TREMONT ST'
#  'NORFOLK ST, TALBOT AVE, WASHINGTON ST'
#  'CRESCENT AVE, DORCHESTER AVE, EAST COTTAGE ST' 'ADAMS ST, GIBSON ST'
#  'DORCHESTER AVE, MELVILLE AVE, PARKMAN ST'
#  'BELFORT ST, DORCHESTER AVE, VICTORIA ST'
#  'DORCHESTER AVE, LONSDALE ST, WELLES AVE' 'ASHMONT ST, DORCHESTER AVE'
#  'DORCHESTER AVE, TALBOT AVE' 'EAST COTTAGE ST, PLEASANT ST'
#  'BOSTON ST, COLUMBIA RD, EAST COTTAGE ST, MASSACHUSETTS AVE'
#  'ELM HILL AVE, WARREN ST' 'BLUE HILL AVE, WOODROW ST'
#  'HUNTINGTON AVE, FIRE STATION #37'
#  'DORCHESTER AVE, MT VERNON ST, ROSECLAIR ST'
#  'BAIRD ST, BLUE HILL AVE, WOODROW ST'
#  'RUGGLES ST, TREMONT ST, WHITTIER ST' 'DORCHESTER AVE, KIMBALL ST'
#  'ADAMS ST, MEDWAY ST' 'HEATH ST @ #251'
#  'DORCHESTER AVE, HOYT ST, HANCOCK ST'
#  'COLUMBUS AVE, MELNEA CASS BLVD, TREMONT ST'
#  'DORCHESTER AVE, SUDAN ST, TAFT ST' 'DORCHESTER AVE, PARK ST'
#  'PARKER ST, TREMONT ST' 'COLUMBUS AVE, MALCOLM X BLVD, TREMONT ST'
#  'CENTRE ST, COLUMBUS AVE, HEATH ST'
#  'COLUMBUS AVE, MALCOM X BLVD, TREMONT ST'
#  'COLUMBUS AVE, RUGGLES ST, TREMONT ST'
#  'HARVARD AVE, VASSAR ST, WASHINGTON ST'
#  'CORNWALL ST, PETER PARLEY RD, WASHINGTON ST' 'BROMLEY ST, HEATH ST'
#  'ADAMS ST, MILTON ST' 'WARREN ST, WAUMBECK HILL'
#  'WALNUT AVE, WARREN ST, WHITING ST' 'MARTIN LUTHER KING BLVD, WARREN ST'
#  'EUSTIS ST, HARRISON AVE' 'HEATH ST, SCHILLER ST'
#  'HARVARD AVE, MAPLE ST, RIVER ST' 'DUDLE ST, HARRISON AVE'
#  'SCHOOL ST, WASHINGTON ST' 'CENTRE ST, JACKSON SQ MBTA STATION'
#  'RUGGLES ST, RUGGLES MBTA STATION BUSWAY' 'BRAY ST, COLUMBUS AVE'
#  'COLUMBUS AVE, DIMOCK ST' 'GURNEY ST, TERRACE ST, TREMONT ST'
#  'CLIFTON ST, EAST COTTAGE ST' 'CENTRE ST, LAMARTINE ST'
#  'CEDAR ST, COLUMBUS AVE' 'COLUMBUS AVE, WELD ST'
#  'COLUMBUS AVE, JACKSON SQ MBTA STATION BUSWAY'
#  'ACCESS DR, RUGGLES ST, TREMONT ST' 'CENTRE ST, COLUMBUS AVE, RITCHIE ST'
#  'BLUE HILL AVE, CUMMINS HWY, RIVER ST' 'COPELAND ST, WARREN ST'
#  'BROOKLINE AVE, DEACONESS RD, JIMMY FUND WAY'
#  'TREMONT ST, HAMMOND ST, DAVENPORT ST'
#  'TREMONT ST, LENOX ST, DOUGLASS PARK' 'TREMONT ST, BURKE ST, ROXSE DR'
#  'TREMONT ST, CAMDEN ST' 'TREMONT ST, MELNEA CASS BLVD'
#  'HARRISON AVE, PALMER ST, SHABAZZ WAY' 'ADAMS ST, MALLET ST'
#  'MORTON ST, OLD MORTON ST' 'COLUMBIA RD, ARION ST'
#  'HEATH ST, NEW HEATH ST, PARKER ST, WENSLEY ST' 'CUMMINS HWY, FAIRWAY ST']

# %%
# extract all unique street names from the "Associated Streets" column
unique_streets = set(Traffic_df['Associated Streets'].str.split(', ', expand=True).stack())

# initialize dictionary to store counts for each street
street_counts = {}

# iterate over each street name and count occurrences in the "Associated Streets" column
for street in unique_streets:
    street_counts[street] = Traffic_df['Associated Streets'].str.contains(street).sum()

# replace all zero values with one
street_counts = {k: 1 if v == 0 else v for k, v in street_counts.items()}

# print the updated street counts
for street, count in street_counts.items():
    print(street, count)
# Out:
# JACKSON SQ MBTA STATION BUSWAY 2
# HUMBOLDT AVE 16
# HEMENWAY ST 2
# MIDDLE SCHOOL DRIVEWAY 2
# BROMLEY ST 2
# HARVARD ST 26
# OAK ST 2
# RITCHIE ST 2
# DUDLE ST 2
# NORTHAMPTON ST 2
# FISHER AVE 2
# ALBAN ST 3
# RIVER ST 11
# PRENTIS ST 2
# MUSEUM RD 2
# LEON ST 3
# REGENT ST 5
# HINCKLEY ST 2
# RUGGLES ST 26
# MAPLE ST 2
# MALCOLM X BLVD 18
# SHOPPING CTR DRIVEWAY 2
# EAST ST 5
# VALENTINE ST 3
# JEROME ST 2
# GIBSON ST 4
# CUNARD ST 2
# ASHMONT ST 10
# AMERICAN LEGION HWY 11
# BURKE ST 4
# ESTRELLA ST 2
# HILL TOP ST 2
# HAMILTON ST 2
# BABSON ST 7
# PEIRSON ST 4
# MILLMONT ST 2
# BISMARCK ST 2
# KERR WAY 5
# FANEUIL ST 2
# GLEN LN 3
# ELMDALE ST 1
# WALNUT AVE 18
# ALLSTATE RD 4
# RUGGLES MBTA STATION BUSWAY 2
# PLEASANT ST 13
# HARRISON AVE 16
# BRINTON ST 3
# EVANS WAY 4
# OLD MORTON ST 4
# FREEPORT ST 5
# HOWLAND ST 4
# WEST COTTAGE ST 1
# CRAWFORD ST 2
# HEATH ST @ #251 2
# WAUMBECK HILL 1
# COLUMBUS AVE @ #2044 2
# RICHMOND ST 2
# FOTTLER RD 2
# ALLEN ST 3
# BALSAM RD 2
# SYDNEY ST 1
# WIGGLESWORTH ST 2
# BELLEVUE ST 3
# LOCUST ST 3
# SHAMUT AVE 3
# GREENBRIER ST 2
# MALCOM X BLVD 1
# GREENFIELD RD 4
#  HUNGTINGTON AVE 5
# WOOD AVE 37
# BLACKFAN ST 2
# DIX ST 3
# NIGHTINGALE ST 4
# TERRACE ST 3
# LENOX ST 6
# MASSACGUSETTS AVE 2
# TOWNSEND ST 9
# BLACKFAN CIRCLE 1
# POMPEII ST 2
# GOODALE RD 6
# CHESTERTON ST 4
# ROSLIN ST 2
# PAULA RD 2
# TEMPLE ST 2
# SHABAZZ WAY 2
# FAULKNER ST 2
# SOUTH HUNTINGTON AVE 7
# MALLET ST 2
# HANCOCK 10
# OLNEY ST 2
# MARTIN LUTHER KING BLVD 4
# NEPONSET AVE 12
# OAKLAND ST 3
# WAVERLY ST 3
# RUTHVEN 8
# WARREN ST,WAUMBECK ST 1
# HAMPDEN ST 6
# NSTAR DRIVEWAY 2
# ST MARKS CHURCH 2
# SOUTHAMPTON ST  2
# DUDLEY ST 19
# WALDECK ST 2
# EDGERLY RD 2
# POND ST 2
# WYOMING ST 2
# ARION ST 1
# FAIRWAY ST 3
# ABBOTSFORD ST 2
# HIGHLAND ST 2
# MASS AVE 37
# DRUMMOND ST 2
# HOOPER ST 3
# BEECHCROFT ST 2
# BRINSLEY ST 2
# CHILDREN'S HOSPITAL 1
# RUSFIELD ST 2
# FORT AVE 4
# FRANKLIN PARK RD 2
# HANCOCK ST 9
# FORSYTH WAY 4
# DORSET ST 3
# BELLFLOWER ST 2
# TAFT ST 2
# VERNON ST 6
# WARD ST 1
# OLD COLONY TERR 2
# LINCOLN ST 2
# PROCTOR ST 3
# BOYLSTON ST 2
# COLUMBIA RD 45
# SUDAN ST 2
# DEVON ST 1
# BALSAM ST 1
# VICTORY RD 2
# SHORT ST 2
# EUSTIS ST 5
# WOOLSON ST 6
# FIRE STATION #37 1
# FESSENDEN ST 1
# FRANCIS ST 15
# WASHINGTON ST 75
# ROXBURY ST CONNECTOR 2
# ISLAND ST 3
# MASSACHUSETTS AVE 12
# WOODROW AVE 5
# INTERVALE ST 3
# VALLEY RD 2
# WESTLAND AVE 2
# TOPEKA ST 2
# MELVILLE AVE 7
# DEACONESS RD 2
# COBDEN ST 2
# NESSEL WAY 2
# #60 2
# WELLINGTON HILL ST 1
# CASTLEGATE RD 4
# BROCKTON ST 2
# BULLARD ST 2
# GENEVA AVE 21
# MARCELLA ST 3
# OAKTON ST 2
# NEW HEATH ST 2
# WALES ST 4
# PALMER ST 2
# DALE ST 20
# RUSSELL ELEMENTARY SCHOOL 2
# SHAWMUT AVE EXT 1
# WENSLEY ST 1
# ADAMS ST 36
# CRESCENT AVE 2
# BROADWAY BRIDGE 2
# EAST COTTAGE ST 17
# HAMMOND ST 4
# ELM HILL AVE 12
# AUTUMN ST 2
# HOYT ST 3
# BLACKFAN CIR 6
# FENWOOD RD 5
# DORCHESTER ST 4
# ERIE ST 2
# GURNEY ST 5
# HELENA RD 2
# CAMDEN ST 4
# ROXSE DR 4
# WESTVIEW ST 2
# VETERANS HOSPITAL 1
# WEST BROADWAY 2
# KIMBALL ST 2
# STRATTON ST 2
# TREMONT ST 57
# D ST 112
# LOUIS PRANG ST 5
# BURGESS ST 2
# WALNUT ST 2
# MLK BVD 1
# SAVIN HILL AVE 5
# REGIS RD 1
# QUINCY ST 14
# WELD ST 4
# GERARD ST 2
# BOWDOIN AVE 2
# MAYFIELD ST 4
# DUNBAR AVE 2
# MT VERNON ST 2
# SHIRLEY ST 5
# RIVERWAYY 2
# BISHOP JOE SMITH WAY 4
# LITHGOW ST 2
# ROSS WAY 2
# WILLIAMS ST 3
# ROWE ST 3
# RECTOR RD 1
# CUSHING AVE 2
# BOUTWELL ST 2
# KEARSARGE AVE 1
# ANNABEL ST 2
# VICTORIA ST 6
# SOUTHAMPTON ST 11
# POPE'S HILL ST 4
# HUNTINGTON AVE 46
# SMITH ST 2
# DEACONESS ST 2
# OLD COLONY AVE 6
# CLIFFORD ST 8
# OAKMAN ST 2
# WINTER ST 6
# CHENEY ST 2
# WYOLA PL 2
# BAIRD ST 1
# WHITING ST 2
# JOHNSTON RD 3
# LAMARTINE ST 2
# RIVERWAY CONNECTOR 2
# JIMMY FUND WAY 4
# WARREN ST @ BOYS CLUB 1
# ROCKLAND ST 4
# FENWAY 5
# SEAVER ST 12
# GLENDALE ST 3
# HUMPHREYS ST 6
# SCHOOL ST 2
# HAROLD ST 2
# HANNON ST 2
# BIRD ST 3
# SHAWMUT AVE 8
# UPLAND AVE 2
# BROOKLINE AVE 23
# SOUTH BAY MALL ENTRANCE 2
# PEARL ST 2
# CLIFTON ST 2
# RIVERWAY 17
# MARTIN LUTHER KING JR BLVD 6
# MLK BLVD 2
# MELNEA CASS BLVD 46
# CLEARWATER DR 4
# CEDAR ST 9
# CLAPP ST 3
# EAST LENOX ST 2
# MARYKNOLL ST 2
# CALUMET ST 4
# MILTON AVE 2
# THEODORE GLYNN WAY 4
# TALBOT AVE 17
# PARISH ST 4
# SAMOSET ST 2
# GLENWAY ST 7
# ATHERTON ST 2
# MEDWAY ST 2
# CEYLON ST 5
# WALK HILL ST 6
# NORMANDY ST 4
# CUMMINS HWY 10
# HEATH ST 12
# WESTERN AVE 2
# PETER PARLEY RD 2
# WHITTIER ST 5
# ANTWERP ST 2
# WOODROW ST 2
# BOWDOIN ST 12
# DIMOCK ST 7
# WELLES AVE 5
# PRENTISS ST 5
# TRULL ST 2
# JULIAN ST 1
# GEORGE ST 3
# KING ST 8
# MAGAZINE ST 9
# DAVENPORT ST 4
# CORNWALL ST 2
# DORCHESTER AVE 63
# BAILEY ST 4
# HEWLETT ST 3
# WILLOWWOOD ST 2
# SOUTH MONROE TERR 2
# MORELAND ST 6
# COLUMBUS AVE 39
# PLEASANT HILL AVE 2
# NEWMARKET SQ 3
# DEWITT DR 2
# PARKMAN ST 4
# VASSAR ST 2
# JACKSON SQ MBTA STATION 4
# HUNTINGTON AVE (S RDWY) 1
# ROSECLAIR ST 2
# WAUMBECK ST 3
# HARVARD AVE 3
# GRANITE AVE 4
# STANDARD ST 4
# NORFOLK ST 12
# OPERA PL 5
# ST ALBANS RD 2
# MARTIN LUTHER KING JR. BLVD 2
# DOUGLASS PARK 4
# MISSION ST 2
# LINDEN ST 2
# LONGWOOD AVE 35
# NEW ENGLAND AVE 2
# TRAIN ST 4
# LONSDALE ST 2
# BINNEY ST 10
# BRUNSWICK ST 4
# RUTHVEN ST 6
# SHOPPING PLAZA 2
# FOLSOM ST 2
# NORFOLK AVE 10
# PARKER ST 20
# COLUMBIA TERRACE 1
# PARK ST 8
# VINING ST 4
# DEERING RD 4
# SCHILLER ST 2
# HOLDEN ST 2
# BOSTON ST 8
# NORWELL SR 2
# WARREN ST 48
# PARKER HILL AVE 3
# DAVERN AVE 1
# FRANKLIN HILL AVE 6
# MORTON ST 7
# MILTON ST 6
# 51 GENEVA AVE 3
# HUNGTINGTON AVE 5
# PARKER HILL ST 2
# CHARLES ST 2
# ASHMONT MBTA BUSWAY 4
# MBTA BUS DR 1
# MISSION PARK DR 3
# BLUE HILL AVE 62
# BRAY ST 2
# COPELAND ST 4
# WARNER ST 2
# ACCESS DR 3
# ST ALPHONSUS ST 1
# CENTRE ST 24
# BELFORT ST 2
# BRADSTON ST 2
# FORSYTH ST 4
# NORWELL ST 3
# ROXBURY ST 9
# COLUMBIA TERR 2
# PILGRIM RD 2
# STOUGHTON ST 3
# FIRE STATION DRIVEWAY 2

# %%
unique_streets = set(Traffic_df['Associated Streets'].str.split(', ', expand=True).stack())

street_counts = {}

for street in unique_streets:
    street_counts[street] = Traffic_df['Associated Streets'].str.contains(street).sum()

one_score_streets = [street for street, count in street_counts.items() if count == 1]

print("Streets with score of one:")
for street in one_score_streets:
    print(street)
# Out:
# Streets with score of one:
# ELMDALE ST
# WEST COTTAGE ST
# WAUMBECK HILL
# SYDNEY ST
# MALCOM X BLVD
# BLACKFAN CIRCLE
# WARREN ST,WAUMBECK ST
# ARION ST
# CHILDREN'S HOSPITAL
# WARD ST
# DEVON ST
# BALSAM ST
# FIRE STATION #37
# FESSENDEN ST
# WELLINGTON HILL ST
# SHAWMUT AVE EXT
# WENSLEY ST
# VETERANS HOSPITAL
# MLK BVD
# REGIS RD
# RECTOR RD
# KEARSARGE AVE
# BAIRD ST
# WARREN ST @ BOYS CLUB
# JULIAN ST
# COLUMBIA TERRACE
# DAVERN AVE
# MBTA BUS DR
# ST ALPHONSUS ST

# %%
# sorted_street_counts = sorted(street_counts.items(), key=lambda x: x[1])

# # extract the 5 most common and 5 least common streets
# most_common_streets = dict(sorted_street_counts[-10:])
# least_common_streets = dict(sorted_street_counts[:10])

# print("5 Most Common Streets:")
# for street, count in most_common_streets.items():
#     print(street, count)

# print("\n5 Least Common Streets:")
# for street, count in least_common_streets.items():
#     print(street, count)

# %%
sorted_street_counts = sorted(street_counts.items(), key=lambda x: x[1])

# extract the 5 most common and 5 least common streets
most_common_streets = dict(sorted_street_counts[-10:])
least_common_streets = dict(sorted_street_counts[:10])

# create horizontal bar graph for most common streets
plt.barh(list(most_common_streets.keys()), list(most_common_streets.values()))
plt.title("10 Most Common Streets")
plt.xlabel("Count")
plt.show()

# create horizontal bar graph for least common streets
plt.barh(list(least_common_streets.keys()), list(least_common_streets.values()))
plt.title("10 Least Common Streets")
plt.xlabel("Count")
plt.show()

# %%
print(Traffic_df['Study Type'].unique())

study_type_counts = Traffic_df['Study Type'].value_counts()
print(study_type_counts)

fig, ax = plt.subplots(figsize=(14, 8))

wedges, labels = ax.pie(study_type_counts.values, startangle=-40, radius=1)

ax.legend(wedges, ['{} ({:.1f}%)'.format(k, v / sum(study_type_counts.values) * 100) for k, v in study_type_counts.items()], title="Study Type", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
ax.set_title("Percentage of Each Study Type")

plt.savefig('../deliverables/TrafficTypes.png')
plt.show()
# Out:
# ['TURNING MOVEMENT COUNT' 'PMC' 'AUTOMATED TRAFFICE RECORDING'
#  'INTERSECTION GAP' 'AUTOMATED TRAFFIC RECORDING' 'SS']
# TURNING MOVEMENT COUNT          831
# AUTOMATED TRAFFICE RECORDING    593
# AUTOMATED TRAFFIC RECORDING      40
# INTERSECTION GAP                 12
# PMC                              11
# SS                                2
# Name: Study Type, dtype: int64
