# %%
# import shapefile
# shape = shapefile.Reader("City_Council_Districts_-_Effective_for_the_2023_Municipal_Election/City_Council_Districts_-_Effective_for_the_2023_Municipal_Election.shp")

import geopandas as gpd
gdf = gpd.read_file("../../data/City_Council_Districts_-_Effective_for_the_2023_Municipal_Election/City_Council_Districts_-_Effective_for_the_2023_Municipal_Election.shp")
print(gdf.head())
# Out:
#    FID    LONGNAME SHORTNAME  DISTRICT      COLOR  TOTAL  TARGET_DEV  \
# 0    1  District 1        D1         1 -851848832  76830        1758
# 1    2  District 2        D2         2  465990528  77466        2394
# 2    3  District 3        D3         3  494969216  73285       -1787
# 3    4  District 4        D4         4     -65408  72917       -2155
# 4    5  District 5        D5         5  412292224  75436         364
#
#    TARGET_D_1  TOTAL18  TOTALHISP  ...  BLACK  AIAN  ASIAN  HPI  OTHER  MLTMN  \
# 0        2.34    64257      24552  ...   3637   783   5080   50  20935   1689
# 1        3.19    70183       6640  ...   4520   269  13604   55   4893   1005
# 2       -2.38    60834      11898  ...  14990   492  13190   45   9927   5357
# 3       -2.87    54939      17409  ...  40030   653   3093   44  11569   7013
# 4        0.48    59652      18191  ...  35584   475   2022   42  12727   4194
#
#    Shape__Are  Shape__Len  DistrictTe  \
# 0    0.002985    0.380208           1
# ...

# %%
type(gdf)
#the data type is GeoDataFrame
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# %matplotlib inline
gdf.plot()
#boston map divided by districts
# Out:
# <AxesSubplot: >

# %% [markdown]
# This is the map of the city council districts, with each district represented by a different color.

# %%
print(gdf.columns)
# Out:
# Index(['FID', 'LONGNAME', 'SHORTNAME', 'DISTRICT', 'COLOR', 'TOTAL',
#        'TARGET_DEV', 'TARGET_D_1', 'TOTAL18', 'TOTALHISP', 'TOTALNH',
#        'WHITENH', 'BLACKNH', 'AIANNH', 'ASIANNH', 'HPINH', 'OTHERNH',
#        'MLTMNNH', 'HISP18', 'NONHISP18', 'WHITENH18', 'BLACKNH18', 'AIANNH18',
#        'ASIANNH18', 'HPINH18', 'OTHERNH18', 'MLTMNNH18', 'WHITE', 'BLACK',
#        'AIAN', 'ASIAN', 'HPI', 'OTHER', 'MLTMN', 'Shape__Are', 'Shape__Len',
#        'DistrictTe', 'geometry'],
#       dtype='object')

# %%
gdf.geometry.name
# Out:
# 'geometry'

# %%
gdf.plot(column='TOTAL')
# Out:
# <AxesSubplot: >

# %% [markdown]
# Districts with higher values are colored darker, while districts with lower values are colored lighter.
#
# The resulting plot shows the same map of the city council districts as before, but with each district colored based on its 'TOTAL' value. The specific color scale and legend will depend on the values in the 'TOTAL' column and the default plotting settings of geopandas.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)

gdf.plot(column='TOTAL', ax=ax, legend=True)
# Out:
# <AxesSubplot: >

# %%
d4 = gdf.loc[[3],'geometry']
d4.plot()
# Out:
# <AxesSubplot: >

# %%
# newdata = gdf.overlay(d4, how='intersection')
# newdata.plot()
#gdf.plot(color=gdf['COLOR'])
type(d4)
# Out:
# geopandas.geoseries.GeoSeries

# %%
fig, ax = plt.subplots(figsize=(10, 10))
gdf.plot(ax=ax)
d4.plot(ax=ax, color='red', alpha=0.5)
# Out:
# <AxesSubplot: >

# %% [markdown]
# This Splot shows all of the city council districts, with district 4 highlighted in red and drawn with an opacity of 0.5.

# %%
fig, ax = plt.subplots(1, 1)

gdf.plot(column='TARGET_DEV', ax=ax, legend=True)
# Out:
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(1, 1)

gdf.plot(column='TARGET_D_1', ax=ax, legend=True)
# Out:
# <AxesSubplot: >
